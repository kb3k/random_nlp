# %% [markdown]
# # Dr. Jennifer Sleeman
# # Exploring Term Extraction Methods
# # jennsleeman@gmail.com

# %%
#Just in case you need to install the appropriate packages uncomment these lines
# !pip3 install phrasemachine
# !pip3 install nltk
# !pip3 install rake_nltk
# Out:
# Collecting phrasemachine
#   Downloading phrasemachine-1.0.7.tar.gz (2.7 MB)
#      |████████████████████████████████| 2.7 MB 1.2 MB/s eta 0:00:01     |█████▏                          | 430 kB 1.2 MB/s eta 0:00:02
# Requirement already satisfied: nltk in /opt/anaconda3/lib/python3.7/site-packages (from phrasemachine) (3.7)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.7/site-packages (from nltk->phrasemachine) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/lib/python3.7/site-packages (from nltk->phrasemachine) (2022.3.15)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.7/site-packages (from nltk->phrasemachine) (8.0.4)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.7/site-packages (from nltk->phrasemachine) (4.64.0)
# Requirement already satisfied: importlib-metadata in /opt/anaconda3/lib/python3.7/site-packages (from click->nltk->phrasemachine) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/lib/python3.7/site-packages (from importlib-metadata->click->nltk->phrasemachine) (3.7.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /opt/anaconda3/lib/python3.7/site-packages (from importlib-metadata->click->nltk->phrasemachine) (4.1.1)
# Building wheels for collected packages: phrasemachine
#   Building wheel for phrasemachine (setup.py) ... done
#   Created wheel for phrasemachine: filename=phrasemachine-1.0.7-py3-none-any.whl size=2694879 sha256=8a481a8f7e2439013d06855dd63e7b22e119b456b3d963d281d3dee68f296317
#   Stored in directory: /Users/kerry/Library/Caches/pip/wheels/49/d9/e6/e8948b0664fc1e5135444099525ae3f67cebc0bcddf0a7b453
# Successfully built phrasemachine
# Installing collected packages: phrasemachine
# Successfully installed phrasemachine-1.0.7
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/opt/anaconda3/bin/python -m pip install --upgrade pip' command.
# Requirement already satisfied: nltk in /opt/anaconda3/lib/python3.7/site-packages (3.7)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.7/site-packages (from nltk) (1.1.0)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.7/site-packages (from nltk) (4.64.0)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.7/site-packages (from nltk) (8.0.4)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/lib/python3.7/site-packages (from nltk) (2022.3.15)
# Requirement already satisfied: importlib-metadata in /opt/anaconda3/lib/python3.7/site-packages (from click->nltk) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/lib/python3.7/site-packages (from importlib-metadata->click->nltk) (3.7.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /opt/anaconda3/lib/python3.7/site-packages (from importlib-metadata->click->nltk) (4.1.1)
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/opt/anaconda3/bin/python -m pip install --upgrade pip' command.
# Collecting rake_nltk
#   Downloading rake_nltk-1.0.6-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: nltk<4.0.0,>=3.6.2 in /opt/anaconda3/lib/python3.7/site-packages (from rake_nltk) (3.7)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.7/site-packages (from nltk<4.0.0,>=3.6.2->rake_nltk) (4.64.0)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.7/site-packages (from nltk<4.0.0,>=3.6.2->rake_nltk) (8.0.4)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/lib/python3.7/site-packages (from nltk<4.0.0,>=3.6.2->rake_nltk) (2022.3.15)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.7/site-packages (from nltk<4.0.0,>=3.6.2->rake_nltk) (1.1.0)
# Requirement already satisfied: importlib-metadata in /opt/anaconda3/lib/python3.7/site-packages (from click->nltk<4.0.0,>=3.6.2->rake_nltk) (4.11.3)
# Requirement already satisfied: typing-extensions>=3.6.4 in /opt/anaconda3/lib/python3.7/site-packages (from importlib-metadata->click->nltk<4.0.0,>=3.6.2->rake_nltk) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /opt/anaconda3/lib/python3.7/site-packages (from importlib-metadata->click->nltk<4.0.0,>=3.6.2->rake_nltk) (3.7.0)
# Installing collected packages: rake-nltk
# Successfully installed rake-nltk-1.0.6
# WARNING: You are using pip version 22.0.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/opt/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
import phrasemachine
import nltk
from rake_nltk import Rake
import re
from nltk.tokenize import word_tokenize 
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.tokenize import RegexpTokenizer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk import ngrams, FreqDist

# %%
# Only run this once, they will be downloaded.
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /Users/kerry/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/kerry/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# Examples
document1 = "Ruth Bader Ginsburg was the second woman appointed to the United States Supreme Court, but she’s probably the first justice to become a full-fledged pop-cultural phenomenon. “RBG,” a loving and informative documentary portrait of Justice Ginsburg during her 85th year on earth and her 25th on the bench, is both evidence of this status and a partial explanation of how it came about.Directed by Betsy West and Julie Cohen, the film is a jaunty assemblage of interviews, public appearances and archival material, organized to illuminate its subject’s temperament and her accomplishments so far. Though it begins with audio snippets of Justice Ginsburg’s right-wing detractors — who see her as a “demon,” a “devil” and a threat to America — “RBG” takes a pointedly high road through recent political controversies. Its celebration of Justice Ginsburg’s record of progressive activism and jurisprudence is partisan but not especially polemical. The filmmakers share her convictions and assume that the audience will, too. Which might be true, and not only because much of the audience is likely to consist of liberals. Before she was named to the federal bench by Jimmy Carter in 1980, the future justice had argued a handful of important sex-discrimination cases in front of the Supreme Court. What linked these cases — she won five out of six — was the theory that the equal protection clause of the 14th Amendment should apply to women and could be used to remedy discrepancies in hiring, business practices and public policy.The idea that women are equal citizens — that barring them from certain jobs and educational opportunities and treating them as the social inferiors of men are unfair — may not seem especially controversial now. “RBG” uses Justice Ginsburg’s own experiences to emphasize how different things were not so long ago. At Harvard Law School, she was one of nine women in a class of hundreds, and was asked by the dean (as all the women were) why she thought she deserved to take what should have been a man’s place.The biographical part of “RBG” tells a story that is both typical and exceptional. It’s a reminder that the upward striving of first- and second-generation Jewish immigrants in the middle decades of the 20th century was accompanied by fervent political idealism. Justice Ginsburg’s career was marked by intense intellectual ambition and also by a determination to use the law as an instrument of change.The film also chronicles her marriage to Martin Ginsburg. They met as undergraduates at Cornell, and for the next 63 years, Mr. Ginsburg (who died in 2010) was his wife’s tireless supporter and champion, a man whose commitment to domestic egalitarianism was extraordinary in his time and far from common today. As their friends and children explain — and as Mr. Ginsburg, a New York tax lawyer, often said himself — he was responsible for cooking meals and cracking jokes while she was making history. He also, when Byron White retired from the Supreme Court, made sure that her name was high on President Clinton’s list of candidates.It would be fascinating to learn more about that campaign, and also to have a finer-grained sense of the institutional and interpersonal dynamics of the court over the past quarter-century. But “RBG” reasonably chooses to focus on Justice Ginsburg herself, and relishes every moment of her company. It also shows why she has become such an inspiration for younger feminists, like Irin Carmon and Shana Knizhnik, whose 2015 book “Notorious RBG: The Life and Times of Ruth Bader Ginsburg” helped created the contemporary image of a fierce, uncompromising and gracious champion of women’s rights.That those rights are in a new phase of embattlement goes without saying. The movie’s touch is light and its spirit buoyant, but there is no mistaking its seriousness or its passion. Those qualities resonate powerfully in the dissents that may prove to be Justice Ginsburg’s most enduring legacy, and “RBG” is, above all, a tribute to her voice."
#Add document variables here or parse your documents from a directory (your choice)

# %%
# Create a list of stop words from nltk
stop_words = set(stopwords.words("english"))

# %%
# Pre-process dataset to remove punctuation
def remove_punctuation(in_text):
    # Remove punctuation
    text = re.sub('[^a-zA-Z]', ' ', str(in_text))
    return text

# %%
# Pre-process dataset to lower case it
def lower_case(in_text):
    # Convert to lowercase
    text = in_text.lower()    
    return text

# %%
# Pre-process dataset to remove tags
def remove_tags(in_text):    
    # Remove tags
    text=re.sub("&lt;/?.*?&gt;"," &lt;&gt; ",in_text)
    return text

# %%
# Pre-process dataset to remove special characters and digits
def remove_special_chars_and_digits(in_text):
    # Remove special characters and digits
    text=re.sub("(\\d|\\W)+"," ",in_text)
    return text

# %%
# Pre-process dataset to appy Stemming
def apply_stemming(in_text):
    stemmer=PorterStemmer()
    word_list = nltk.word_tokenize(in_text)
    output = ' '.join([stemmer.stem(w) for w in word_list])
    return output

# %%
# Pre-process dataset to apply Lemmatization
def apply_lemmatization(in_text):
    # Lemmatization
    lem = WordNetLemmatizer()
    word_list = nltk.word_tokenize(in_text)
    output = ' '.join([lem.lemmatize(w) for w in word_list])
    return output

# %%
# Remove stop words
def remove_stop_words(in_text):
    stop_words = set(stopwords.words('english')) 
    word_tokens = word_tokenize(in_text)  
    filtered_sentence = [w for w in word_tokens if not w in stop_words] 
    filtered_sentence = [] 
    for w in word_tokens: 
        if w not in stop_words: 
            filtered_sentence.append(w) 

    return filtered_sentence

# %%
# Run Phase Machine
def run_phrase_machine(in_text):
    phrases=phrasemachine.get_phrases(in_text)
    return phrases

# %%
#Run Rake Keyword Extractor
def run_rake(in_text):
    r = Rake()
    r.extract_keywords_from_text(in_text)
    rake_phrases= r.get_ranked_phrases()
    return rake_phrases

# %%
# Run NLTK Tokenizer
def run_nltk_tokenizer(in_text):
    tokens=nltk.word_tokenize(in_text)
    return tokens

# %%
# Run NLTK Sentence Tokenizer
def run_nltk_sent_tokenizer(in_corpus):
    sents = nltk.sent_tokenize(in_corpus)
    return sents

# %%
#Run word-ngram Tokenizer
def run_nltk_tokenizer_word_ngrams(in_text, ngram_size):
    n_grams = ngrams(nltk.word_tokenize(in_text), ngram_size)
    return [ ' '.join(grams) for grams in n_grams]

# %%
#Get Frequ Dist 
def get_freq_dist(terms):
    all_counts = dict()
    all_counts = FreqDist(terms)
    return all_counts

# %%
#Run this first to get sentences from text.
sentences=run_nltk_sent_tokenizer(document1)

# %%
#Explore different extractors and difference preprocessing techniques
for sentence in sentences:
    print(sentence)
    print("===================NLTK Tokenizer===================")
    print(run_nltk_tokenizer(sentence))
    print("===================NLTK Word NGRAM Tokenizer 2 words===================")
    print(run_nltk_tokenizer_word_ngrams(sentence,2))
    print("===================NLTK Word NGRAM Tokenizer 3 words===================")
    print(run_nltk_tokenizer_word_ngrams(sentence,3))
    print("===================Phrase Machine===================")
    phrases=run_phrase_machine(sentence)
    for term in phrases["counts"].keys():
        print(term)
    print("===================Rake===================")
    print(run_rake(sentence))
    print("===================NLTK Tokenizer===================")
    print(run_nltk_tokenizer((sentence)))
    print("===================NLTK Tokenizer LOWER CASE===================")
    print(run_nltk_tokenizer(lower_case(sentence)))
    print("===================NLTK Tokenizer REMOVE STOP WORDS===================")
    print(remove_stop_words(sentence))   
    print("===================NLTK Tokenizer REMOVED PUNCTUATION===================")
    print(run_nltk_tokenizer(remove_punctuation(sentence)))
    print("===================NLTK Tokenizer REMOVED TAGS===================")
    print(run_nltk_tokenizer(remove_tags(sentence)))
    print("===================NLTK Tokenizer REMOVED CHARS AND DIGITS===================")
    print(run_nltk_tokenizer(remove_special_chars_and_digits(sentence)))
    print("===================NLTK Tokenizer STEMMING APPLIED===================")
    print(run_nltk_tokenizer(apply_stemming(sentence)))
    print("===================NLTK Tokenizer LEMMATIZATION APPLIED===================")
    print(run_nltk_tokenizer(apply_lemmatization(sentence)))
    #break
# Out:
# Ruth Bader Ginsburg was the second woman appointed to the United States Supreme Court, but she’s probably the first justice to become a full-fledged pop-cultural phenomenon.
# ===================NLTK Tokenizer===================
# ['Ruth', 'Bader', 'Ginsburg', 'was', 'the', 'second', 'woman', 'appointed', 'to', 'the', 'United', 'States', 'Supreme', 'Court', ',', 'but', 'she', '’', 's', 'probably', 'the', 'first', 'justice', 'to', 'become', 'a', 'full-fledged', 'pop-cultural', 'phenomenon', '.']
# ===================NLTK Word NGRAM Tokenizer 2 words===================
# ['Ruth Bader', 'Bader Ginsburg', 'Ginsburg was', 'was the', 'the second', 'second woman', 'woman appointed', 'appointed to', 'to the', 'the United', 'United States', 'States Supreme', 'Supreme Court', 'Court ,', ', but', 'but she', 'she ’', '’ s', 's probably', 'probably the', 'the first', 'first justice', 'justice to', 'to become', 'become a', 'a full-fledged', 'full-fledged pop-cultural', 'pop-cultural phenomenon', 'phenomenon .']
# ===================NLTK Word NGRAM Tokenizer 3 words===================
# ['Ruth Bader Ginsburg', 'Bader Ginsburg was', 'Ginsburg was the', 'was the second', 'the second woman', 'second woman appointed', 'woman appointed to', 'appointed to the', 'to the United', 'the United States', 'United States Supreme', 'States Supreme Court', 'Supreme Court ,', 'Court , but', ', but she', 'but she ’', 'she ’ s', '’ s probably', 's probably the', 'probably the first', 'the first justice', 'first justice to', 'justice to become', 'to become a', 'become a full-fledged', 'a full-fledged pop-cultural', 'full-fledged pop-cultural phenomenon', 'pop-cultural phenomenon .']
# ===================Phrase Machine===================
# ruth bader
# ruth bader ginsburg
# bader ginsburg
# second woman
# united states
# united states supreme
# united states supreme court
# states supreme
# states supreme court
# supreme court
# first justice
# full-fledged pop-cultural phenomenon
# pop-cultural phenomenon
# ===================Rake===================
# ['united states supreme court', 'second woman appointed', 'ruth bader ginsburg', 'fledged pop', 'first justice', 'cultural phenomenon', '’', 'probably', 'full', 'become']
# ===================NLTK Tokenizer===================
# ['Ruth', 'Bader', 'Ginsburg', 'was', 'the', 'second', 'woman', 'appointed', 'to', 'the', 'United', 'States', 'Supreme', 'Court', ',', 'but', 'she', '’', 's', 'probably', 'the', 'first', 'justice', 'to', 'become', 'a', 'full-fledged', 'pop-cultural', 'phenomenon', '.']
# ===================NLTK Tokenizer LOWER CASE===================
# ['ruth', 'bader', 'ginsburg', 'was', 'the', 'second', 'woman', 'appointed', 'to', 'the', 'united', 'states', 'supreme', 'court', ',', 'but', 'she', '’', 's', 'probably', 'the', 'first', 'justice', 'to', 'become', 'a', 'full-fledged', 'pop-cultural', 'phenomenon', '.']
# ===================NLTK Tokenizer REMOVE STOP WORDS===================
# ['Ruth', 'Bader', 'Ginsburg', 'second', 'woman', 'appointed', 'United', 'States', 'Supreme', 'Court', ',', '’', 'probably', 'first', 'justice', 'become', 'full-fledged', 'pop-cultural', 'phenomenon', '.']
# ===================NLTK Tokenizer REMOVED PUNCTUATION===================
# ['Ruth', 'Bader', 'Ginsburg', 'was', 'the', 'second', 'woman', 'appointed', 'to', 'the', 'United', 'States', 'Supreme', 'Court', 'but', 'she', 's', 'probably', 'the', 'first', 'justice', 'to', 'become', 'a', 'full', 'fledged', 'pop', 'cultural', 'phenomenon']
# ===================NLTK Tokenizer REMOVED TAGS===================
# ['Ruth', 'Bader', 'Ginsburg', 'was', 'the', 'second', 'woman', 'appointed', 'to', 'the', 'United', 'States', 'Supreme', 'Court', ',', 'but', 'she', '’', 's', 'probably', 'the', 'first', 'justice', 'to', 'become', 'a', 'full-fledged', 'pop-cultural', 'phenomenon', '.']
# ===================NLTK Tokenizer REMOVED CHARS AND DIGITS===================
# ['Ruth', 'Bader', 'Ginsburg', 'was', 'the', 'second', 'woman', 'appointed', 'to', 'the', 'United', 'States', 'Supreme', 'Court', 'but', 'she', 's', 'probably', 'the', 'first', 'justice', 'to', 'become', 'a', 'full', 'fledged', 'pop', 'cultural', 'phenomenon']
# ===================NLTK Tokenizer STEMMING APPLIED===================
# ['ruth', 'bader', 'ginsburg', 'wa', 'the', 'second', 'woman', 'appoint', 'to', 'the', 'unit', 'state', 'suprem', 'court', ',', 'but', 'she', '’', 's', 'probabl', 'the', 'first', 'justic', 'to', 'becom', 'a', 'full-fledg', 'pop-cultur', 'phenomenon', '.']
# ===================NLTK Tokenizer LEMMATIZATION APPLIED===================
# ['Ruth', 'Bader', 'Ginsburg', 'wa', 'the', 'second', 'woman', 'appointed', 'to', 'the', 'United', 'States', 'Supreme', 'Court', ',', 'but', 'she', '’', 's', 'probably', 'the', 'first', 'justice', 'to', 'become', 'a', 'full-fledged', 'pop-cultural', 'phenomenon', '.']
# “RBG,” a loving and informative documentary portrait of Justice Ginsburg during her 85th year on earth and her 25th on the bench, is both evidence of this status and a partial explanation of how it came about.Directed by Betsy West and Julie Cohen, the film is a jaunty assemblage of interviews, public appearances and archival material, organized to illuminate its subject’s temperament and her accomplishments so far.
# ===================NLTK Tokenizer===================
# ['“', 'RBG', ',', '”', 'a', 'loving', 'and', 'informative', 'documentary', 'portrait', 'of', 'Justice', 'Ginsburg', 'during', 'her', '85th', 'year', 'on', 'earth', 'and', 'her', '25th', 'on', 'the', 'bench', ',', 'is', 'both', 'evidence', 'of', 'this', 'status', 'and', 'a', 'partial', 'explanation', 'of', 'how', 'it', 'came', 'about.Directed', 'by', 'Betsy', 'West', 'and', 'Julie', 'Cohen', ',', 'the', 'film', 'is', 'a', 'jaunty', 'assemblage', 'of', 'interviews', ',', 'public', 'appearances', 'and', 'archival', 'material', ',', 'organized', 'to', 'illuminate', 'its', 'subject', '’', 's', 'temperament', 'and', 'her', 'accomplishments', 'so', 'far', '.']
# ===================NLTK Word NGRAM Tokenizer 2 words===================
# ['“ RBG', 'RBG ,', ', ”', '” a', 'a loving', 'loving and', 'and informative', 'informative documentary', 'documentary portrait', 'portrait of', 'of Justice', 'Justice Ginsburg', 'Ginsburg during', 'during her', 'her 85th', '85th year', 'year on', 'on earth', 'earth and', 'and her', 'her 25th', '25th on', 'on the', 'the bench', 'bench ,', ', is', 'is both', 'both evidence', 'evidence of', 'of this', 'this status', 'status and', 'and a', 'a partial', 'partial explanation', 'explanation of', 'of how', 'how it', 'it came', 'came about.Directed', 'about.Directed by', 'by Betsy', 'Betsy West', 'West and', 'and Julie', 'Julie Cohen', 'Cohen ,', ', the', 'the film', 'film is', 'is a', 'a jaunty', 'jaunty assemblage', 'assemblage of', 'of interviews', 'interviews ,', ', public', 'public appearances', 'appearances and', 'and archival', 'archival material', 'material ,', ', organized', 'organized to', 'to illuminate', 'illuminate its', 'its subject', 'subject ’', '’ s', 's temperament', 'temperament and', 'and her', 'her accomplishments', 'accomplishments so', 'so far', 'far .']
# ===================NLTK Word NGRAM Tokenizer 3 words===================
# ['“ RBG ,', 'RBG , ”', ', ” a', '” a loving', 'a loving and', 'loving and informative', 'and informative documentary', 'informative documentary portrait', 'documentary portrait of', 'portrait of Justice', 'of Justice Ginsburg', 'Justice Ginsburg during', 'Ginsburg during her', 'during her 85th', 'her 85th year', '85th year on', 'year on earth', 'on earth and', 'earth and her', 'and her 25th', 'her 25th on', '25th on the', 'on the bench', 'the bench ,', 'bench , is', ', is both', 'is both evidence', 'both evidence of', 'evidence of this', 'of this status', 'this status and', 'status and a', 'and a partial', 'a partial explanation', 'partial explanation of', 'explanation of how', 'of how it', 'how it came', 'it came about.Directed', 'came about.Directed by', 'about.Directed by Betsy', 'by Betsy West', 'Betsy West and', 'West and Julie', 'and Julie Cohen', 'Julie Cohen ,', 'Cohen , the', ', the film', 'the film is', 'film is a', 'is a jaunty', 'a jaunty assemblage', 'jaunty assemblage of', 'assemblage of interviews', 'of interviews ,', 'interviews , public', ', public appearances', 'public appearances and', 'appearances and archival', 'and archival material', 'archival material ,', 'material , organized', ', organized to', 'organized to illuminate', 'to illuminate its', 'illuminate its subject', 'its subject ’', 'subject ’ s', '’ s temperament', 's temperament and', 'temperament and her', 'and her accomplishments', 'her accomplishments so', 'accomplishments so far', 'so far .']
# ===================Phrase Machine===================
# informative documentary portrait
# informative documentary portrait of justice
# informative documentary portrait of justice ginsburg
# documentary portrait
# documentary portrait of justice
# documentary portrait of justice ginsburg
# portrait of justice
# portrait of justice ginsburg
# justice ginsburg
# 85th year
# 85th year on earth
# year on earth
# evidence of this status
# partial explanation
# betsy west
# julie cohen
# jaunty assemblage
# jaunty assemblage of interviews
# assemblage of interviews
# public appearances
# archival material
# subject’s temperament
# ===================Rake===================
# ['“ rbg ,”', 'informative documentary portrait', 'subject ’', 'public appearances', 'partial explanation', 'justice ginsburg', 'julie cohen', 'jaunty assemblage', 'betsy west', 'archival material', '85th year', 'temperament', 'status', 'organized', 'loving', 'interviews', 'illuminate', 'film', 'far', 'evidence', 'earth', 'directed', 'came', 'bench', 'accomplishments', '25th']
# ===================NLTK Tokenizer===================
# ['“', 'RBG', ',', '”', 'a', 'loving', 'and', 'informative', 'documentary', 'portrait', 'of', 'Justice', 'Ginsburg', 'during', 'her', '85th', 'year', 'on', 'earth', 'and', 'her', '25th', 'on', 'the', 'bench', ',', 'is', 'both', 'evidence', 'of', 'this', 'status', 'and', 'a', 'partial', 'explanation', 'of', 'how', 'it', 'came', 'about.Directed', 'by', 'Betsy', 'West', 'and', 'Julie', 'Cohen', ',', 'the', 'film', 'is', 'a', 'jaunty', 'assemblage', 'of', 'interviews', ',', 'public', 'appearances', 'and', 'archival', 'material', ',', 'organized', 'to', 'illuminate', 'its', 'subject', '’', 's', 'temperament', 'and', 'her', 'accomplishments', 'so', 'far', '.']
# ===================NLTK Tokenizer LOWER CASE===================
# ['“', 'rbg', ',', '”', 'a', 'loving', 'and', 'informative', 'documentary', 'portrait', 'of', 'justice', 'ginsburg', 'during', 'her', '85th', 'year', 'on', 'earth', 'and', 'her', '25th', 'on', 'the', 'bench', ',', 'is', 'both', 'evidence', 'of', 'this', 'status', 'and', 'a', 'partial', 'explanation', 'of', 'how', 'it', 'came', 'about.directed', 'by', 'betsy', 'west', 'and', 'julie', 'cohen', ',', 'the', 'film', 'is', 'a', 'jaunty', 'assemblage', 'of', 'interviews', ',', 'public', 'appearances', 'and', 'archival', 'material', ',', 'organized', 'to', 'illuminate', 'its', 'subject', '’', 's', 'temperament', 'and', 'her', 'accomplishments', 'so', 'far', '.']
# ===================NLTK Tokenizer REMOVE STOP WORDS===================
# ['“', 'RBG', ',', '”', 'loving', 'informative', 'documentary', 'portrait', 'Justice', 'Ginsburg', '85th', 'year', 'earth', '25th', 'bench', ',', 'evidence', 'status', 'partial', 'explanation', 'came', 'about.Directed', 'Betsy', 'West', 'Julie', 'Cohen', ',', 'film', 'jaunty', 'assemblage', 'interviews', ',', 'public', 'appearances', 'archival', 'material', ',', 'organized', 'illuminate', 'subject', '’', 'temperament', 'accomplishments', 'far', '.']
# ===================NLTK Tokenizer REMOVED PUNCTUATION===================
# ['RBG', 'a', 'loving', 'and', 'informative', 'documentary', 'portrait', 'of', 'Justice', 'Ginsburg', 'during', 'her', 'th', 'year', 'on', 'earth', 'and', 'her', 'th', 'on', 'the', 'bench', 'is', 'both', 'evidence', 'of', 'this', 'status', 'and', 'a', 'partial', 'explanation', 'of', 'how', 'it', 'came', 'about', 'Directed', 'by', 'Betsy', 'West', 'and', 'Julie', 'Cohen', 'the', 'film', 'is', 'a', 'jaunty', 'assemblage', 'of', 'interviews', 'public', 'appearances', 'and', 'archival', 'material', 'organized', 'to', 'illuminate', 'its', 'subject', 's', 'temperament', 'and', 'her', 'accomplishments', 'so', 'far']
# ===================NLTK Tokenizer REMOVED TAGS===================
# ['“', 'RBG', ',', '”', 'a', 'loving', 'and', 'informative', 'documentary', 'portrait', 'of', 'Justice', 'Ginsburg', 'during', 'her', '85th', 'year', 'on', 'earth', 'and', 'her', '25th', 'on', 'the', 'bench', ',', 'is', 'both', 'evidence', 'of', 'this', 'status', 'and', 'a', 'partial', 'explanation', 'of', 'how', 'it', 'came', 'about.Directed', 'by', 'Betsy', 'West', 'and', 'Julie', 'Cohen', ',', 'the', 'film', 'is', 'a', 'jaunty', 'assemblage', 'of', 'interviews', ',', 'public', 'appearances', 'and', 'archival', 'material', ',', 'organized', 'to', 'illuminate', 'its', 'subject', '’', 's', 'temperament', 'and', 'her', 'accomplishments', 'so', 'far', '.']
# ===================NLTK Tokenizer REMOVED CHARS AND DIGITS===================
# ['RBG', 'a', 'loving', 'and', 'informative', 'documentary', 'portrait', 'of', 'Justice', 'Ginsburg', 'during', 'her', 'th', 'year', 'on', 'earth', 'and', 'her', 'th', 'on', 'the', 'bench', 'is', 'both', 'evidence', 'of', 'this', 'status', 'and', 'a', 'partial', 'explanation', 'of', 'how', 'it', 'came', 'about', 'Directed', 'by', 'Betsy', 'West', 'and', 'Julie', 'Cohen', 'the', 'film', 'is', 'a', 'jaunty', 'assemblage', 'of', 'interviews', 'public', 'appearances', 'and', 'archival', 'material', 'organized', 'to', 'illuminate', 'its', 'subject', 's', 'temperament', 'and', 'her', 'accomplishments', 'so', 'far']
# ===================NLTK Tokenizer STEMMING APPLIED===================
# ['“', 'rbg', ',', '”', 'a', 'love', 'and', 'inform', 'documentari', 'portrait', 'of', 'justic', 'ginsburg', 'dure', 'her', '85th', 'year', 'on', 'earth', 'and', 'her', '25th', 'on', 'the', 'bench', ',', 'is', 'both', 'evid', 'of', 'thi', 'statu', 'and', 'a', 'partial', 'explan', 'of', 'how', 'it', 'came', 'about.direct', 'by', 'betsi', 'west', 'and', 'juli', 'cohen', ',', 'the', 'film', 'is', 'a', 'jaunti', 'assemblag', 'of', 'interview', ',', 'public', 'appear', 'and', 'archiv', 'materi', ',', 'organ', 'to', 'illumin', 'it', 'subject', '’', 's', 'tempera', 'and', 'her', 'accomplish', 'so', 'far', '.']
# ===================NLTK Tokenizer LEMMATIZATION APPLIED===================
# ['“', 'RBG', ',', '”', 'a', 'loving', 'and', 'informative', 'documentary', 'portrait', 'of', 'Justice', 'Ginsburg', 'during', 'her', '85th', 'year', 'on', 'earth', 'and', 'her', '25th', 'on', 'the', 'bench', ',', 'is', 'both', 'evidence', 'of', 'this', 'status', 'and', 'a', 'partial', 'explanation', 'of', 'how', 'it', 'came', 'about.Directed', 'by', 'Betsy', 'West', 'and', 'Julie', 'Cohen', ',', 'the', 'film', 'is', 'a', 'jaunty', 'assemblage', 'of', 'interview', ',', 'public', 'appearance', 'and', 'archival', 'material', ',', 'organized', 'to', 'illuminate', 'it', 'subject', '’', 's', 'temperament', 'and', 'her', 'accomplishment', 'so', 'far', '.']
# Though it begins with audio snippets of Justice Ginsburg’s right-wing detractors — who see her as a “demon,” a “devil” and a threat to America — “RBG” takes a pointedly high road through recent political controversies.
# ===================NLTK Tokenizer===================
# ['Though', 'it', 'begins', 'with', 'audio', 'snippets', 'of', 'Justice', 'Ginsburg', '’', 's', 'right-wing', 'detractors', '—', 'who', 'see', 'her', 'as', 'a', '“', 'demon', ',', '”', 'a', '“', 'devil', '”', 'and', 'a', 'threat', 'to', 'America', '—', '“', 'RBG', '”', 'takes', 'a', 'pointedly', 'high', 'road', 'through', 'recent', 'political', 'controversies', '.']
# ===================NLTK Word NGRAM Tokenizer 2 words===================
# ['Though it', 'it begins', 'begins with', 'with audio', 'audio snippets', 'snippets of', 'of Justice', 'Justice Ginsburg', 'Ginsburg ’', '’ s', 's right-wing', 'right-wing detractors', 'detractors —', '— who', 'who see', 'see her', 'her as', 'as a', 'a “', '“ demon', 'demon ,', ', ”', '” a', 'a “', '“ devil', 'devil ”', '” and', 'and a', 'a threat', 'threat to', 'to America', 'America —', '— “', '“ RBG', 'RBG ”', '” takes', 'takes a', 'a pointedly', 'pointedly high', 'high road', 'road through', 'through recent', 'recent political', 'political controversies', 'controversies .']
# ===================NLTK Word NGRAM Tokenizer 3 words===================
# ['Though it begins', 'it begins with', 'begins with audio', 'with audio snippets', 'audio snippets of', 'snippets of Justice', 'of Justice Ginsburg', 'Justice Ginsburg ’', 'Ginsburg ’ s', '’ s right-wing', 's right-wing detractors', 'right-wing detractors —', 'detractors — who', '— who see', 'who see her', 'see her as', 'her as a', 'as a “', 'a “ demon', '“ demon ,', 'demon , ”', ', ” a', '” a “', 'a “ devil', '“ devil ”', 'devil ” and', '” and a', 'and a threat', 'a threat to', 'threat to America', 'to America —', 'America — “', '— “ RBG', '“ RBG ”', 'RBG ” takes', '” takes a', 'takes a pointedly', 'a pointedly high', 'pointedly high road', 'high road through', 'road through recent', 'through recent political', 'recent political controversies', 'political controversies .']
# ===================Phrase Machine===================
# audio snippets
# audio snippets of justice
# audio snippets of justice ginsburg’s
# audio snippets of justice ginsburg’s right-wing detractors
# snippets of justice
# snippets of justice ginsburg’s
# snippets of justice ginsburg’s right-wing detractors
# justice ginsburg’s
# justice ginsburg’s right-wing detractors
# ginsburg’s right-wing detractors
# right-wing detractors
# threat to america
# threat to america —
# threat to america — “rbg”
# america —
# america — “rbg”
# — “rbg”
# high road
# high road through recent political controversies
# road through recent political controversies
# recent political controversies
# political controversies
# ===================Rake===================
# ['america — “ rbg ” takes', '“ devil ”', 'wing detractors —', '“ demon ,”', 'recent political controversies', 'pointedly high road', 'justice ginsburg ’', 'audio snippets', 'threat', 'though', 'see', 'right', 'begins']
# ===================NLTK Tokenizer===================
# ['Though', 'it', 'begins', 'with', 'audio', 'snippets', 'of', 'Justice', 'Ginsburg', '’', 's', 'right-wing', 'detractors', '—', 'who', 'see', 'her', 'as', 'a', '“', 'demon', ',', '”', 'a', '“', 'devil', '”', 'and', 'a', 'threat', 'to', 'America', '—', '“', 'RBG', '”', 'takes', 'a', 'pointedly', 'high', 'road', 'through', 'recent', 'political', 'controversies', '.']
# ===================NLTK Tokenizer LOWER CASE===================
# ['though', 'it', 'begins', 'with', 'audio', 'snippets', 'of', 'justice', 'ginsburg', '’', 's', 'right-wing', 'detractors', '—', 'who', 'see', 'her', 'as', 'a', '“', 'demon', ',', '”', 'a', '“', 'devil', '”', 'and', 'a', 'threat', 'to', 'america', '—', '“', 'rbg', '”', 'takes', 'a', 'pointedly', 'high', 'road', 'through', 'recent', 'political', 'controversies', '.']
# ===================NLTK Tokenizer REMOVE STOP WORDS===================
# ['Though', 'begins', 'audio', 'snippets', 'Justice', 'Ginsburg', '’', 'right-wing', 'detractors', '—', 'see', '“', 'demon', ',', '”', '“', 'devil', '”', 'threat', 'America', '—', '“', 'RBG', '”', 'takes', 'pointedly', 'high', 'road', 'recent', 'political', 'controversies', '.']
# ===================NLTK Tokenizer REMOVED PUNCTUATION===================
# ['Though', 'it', 'begins', 'with', 'audio', 'snippets', 'of', 'Justice', 'Ginsburg', 's', 'right', 'wing', 'detractors', 'who', 'see', 'her', 'as', 'a', 'demon', 'a', 'devil', 'and', 'a', 'threat', 'to', 'America', 'RBG', 'takes', 'a', 'pointedly', 'high', 'road', 'through', 'recent', 'political', 'controversies']
# ===================NLTK Tokenizer REMOVED TAGS===================
# ['Though', 'it', 'begins', 'with', 'audio', 'snippets', 'of', 'Justice', 'Ginsburg', '’', 's', 'right-wing', 'detractors', '—', 'who', 'see', 'her', 'as', 'a', '“', 'demon', ',', '”', 'a', '“', 'devil', '”', 'and', 'a', 'threat', 'to', 'America', '—', '“', 'RBG', '”', 'takes', 'a', 'pointedly', 'high', 'road', 'through', 'recent', 'political', 'controversies', '.']
# ===================NLTK Tokenizer REMOVED CHARS AND DIGITS===================
# ['Though', 'it', 'begins', 'with', 'audio', 'snippets', 'of', 'Justice', 'Ginsburg', 's', 'right', 'wing', 'detractors', 'who', 'see', 'her', 'as', 'a', 'demon', 'a', 'devil', 'and', 'a', 'threat', 'to', 'America', 'RBG', 'takes', 'a', 'pointedly', 'high', 'road', 'through', 'recent', 'political', 'controversies']
# ===================NLTK Tokenizer STEMMING APPLIED===================
# ['though', 'it', 'begin', 'with', 'audio', 'snippet', 'of', 'justic', 'ginsburg', '’', 's', 'right-w', 'detractor', '—', 'who', 'see', 'her', 'as', 'a', '“', 'demon', ',', '”', 'a', '“', 'devil', '”', 'and', 'a', 'threat', 'to', 'america', '—', '“', 'rbg', '”', 'take', 'a', 'pointedli', 'high', 'road', 'through', 'recent', 'polit', 'controversi', '.']
# ===================NLTK Tokenizer LEMMATIZATION APPLIED===================
# ['Though', 'it', 'begin', 'with', 'audio', 'snippet', 'of', 'Justice', 'Ginsburg', '’', 's', 'right-wing', 'detractor', '—', 'who', 'see', 'her', 'a', 'a', '“', 'demon', ',', '”', 'a', '“', 'devil', '”', 'and', 'a', 'threat', 'to', 'America', '—', '“', 'RBG', '”', 'take', 'a', 'pointedly', 'high', 'road', 'through', 'recent', 'political', 'controversy', '.']
# Its celebration of Justice Ginsburg’s record of progressive activism and jurisprudence is partisan but not especially polemical.
# ===================NLTK Tokenizer===================
# ['Its', 'celebration', 'of', 'Justice', 'Ginsburg', '’', 's', 'record', 'of', 'progressive', 'activism', 'and', 'jurisprudence', 'is', 'partisan', 'but', 'not', 'especially', 'polemical', '.']
# ===================NLTK Word NGRAM Tokenizer 2 words===================
# ['Its celebration', 'celebration of', 'of Justice', 'Justice Ginsburg', 'Ginsburg ’', '’ s', 's record', 'record of', 'of progressive', 'progressive activism', 'activism and', 'and jurisprudence', 'jurisprudence is', 'is partisan', 'partisan but', 'but not', 'not especially', 'especially polemical', 'polemical .']
# ===================NLTK Word NGRAM Tokenizer 3 words===================
# ['Its celebration of', 'celebration of Justice', 'of Justice Ginsburg', 'Justice Ginsburg ’', 'Ginsburg ’ s', '’ s record', 's record of', 'record of progressive', 'of progressive activism', 'progressive activism and', 'activism and jurisprudence', 'and jurisprudence is', 'jurisprudence is partisan', 'is partisan but', 'partisan but not', 'but not especially', 'not especially polemical', 'especially polemical .']
# ===================Phrase Machine===================
# celebration of justice
# celebration of justice ginsburg’s
# celebration of justice ginsburg’s record
# celebration of justice ginsburg’s record of progressive activism
# justice ginsburg’s
# justice ginsburg’s record
# justice ginsburg’s record of progressive activism
# ginsburg’s record
# ginsburg’s record of progressive activism
# record of progressive activism
# progressive activism
# ===================Rake===================
# ['justice ginsburg ’', 'progressive activism', 'especially polemical', 'record', 'partisan', 'jurisprudence', 'celebration']
# ===================NLTK Tokenizer===================
# ['Its', 'celebration', 'of', 'Justice', 'Ginsburg', '’', 's', 'record', 'of', 'progressive', 'activism', 'and', 'jurisprudence', 'is', 'partisan', 'but', 'not', 'especially', 'polemical', '.']
# ===================NLTK Tokenizer LOWER CASE===================
# ['its', 'celebration', 'of', 'justice', 'ginsburg', '’', 's', 'record', 'of', 'progressive', 'activism', 'and', 'jurisprudence', 'is', 'partisan', 'but', 'not', 'especially', 'polemical', '.']
# ===================NLTK Tokenizer REMOVE STOP WORDS===================
# ['Its', 'celebration', 'Justice', 'Ginsburg', '’', 'record', 'progressive', 'activism', 'jurisprudence', 'partisan', 'especially', 'polemical', '.']
# ===================NLTK Tokenizer REMOVED PUNCTUATION===================
# ['Its', 'celebration', 'of', 'Justice', 'Ginsburg', 's', 'record', 'of', 'progressive', 'activism', 'and', 'jurisprudence', 'is', 'partisan', 'but', 'not', 'especially', 'polemical']
# ===================NLTK Tokenizer REMOVED TAGS===================
# ['Its', 'celebration', 'of', 'Justice', 'Ginsburg', '’', 's', 'record', 'of', 'progressive', 'activism', 'and', 'jurisprudence', 'is', 'partisan', 'but', 'not', 'especially', 'polemical', '.']
# ===================NLTK Tokenizer REMOVED CHARS AND DIGITS===================
# ['Its', 'celebration', 'of', 'Justice', 'Ginsburg', 's', 'record', 'of', 'progressive', 'activism', 'and', 'jurisprudence', 'is', 'partisan', 'but', 'not', 'especially', 'polemical']
# ===================NLTK Tokenizer STEMMING APPLIED===================
# ['it', 'celebr', 'of', 'justic', 'ginsburg', '’', 's', 'record', 'of', 'progress', 'activ', 'and', 'jurisprud', 'is', 'partisan', 'but', 'not', 'especi', 'polem', '.']
# ===================NLTK Tokenizer LEMMATIZATION APPLIED===================
# ['Its', 'celebration', 'of', 'Justice', 'Ginsburg', '’', 's', 'record', 'of', 'progressive', 'activism', 'and', 'jurisprudence', 'is', 'partisan', 'but', 'not', 'especially', 'polemical', '.']
# The filmmakers share her convictions and assume that the audience will, too.
# ===================NLTK Tokenizer===================
# ['The', 'filmmakers', 'share', 'her', 'convictions', 'and', 'assume', 'that', 'the', 'audience', 'will', ',', 'too', '.']
# ===================NLTK Word NGRAM Tokenizer 2 words===================
# ['The filmmakers', 'filmmakers share', 'share her', 'her convictions', 'convictions and', 'and assume', 'assume that', 'that the', 'the audience', 'audience will', 'will ,', ', too', 'too .']
# ===================NLTK Word NGRAM Tokenizer 3 words===================
# ['The filmmakers share', 'filmmakers share her', 'share her convictions', 'her convictions and', 'convictions and assume', 'and assume that', 'assume that the', 'that the audience', 'the audience will', 'audience will ,', 'will , too', ', too .']
# ===================Phrase Machine===================
# filmmakers share
# ===================Rake===================
# ['filmmakers share', 'convictions', 'audience', 'assume']
# ===================NLTK Tokenizer===================
# ['The', 'filmmakers', 'share', 'her', 'convictions', 'and', 'assume', 'that', 'the', 'audience', 'will', ',', 'too', '.']
# ===================NLTK Tokenizer LOWER CASE===================
# ['the', 'filmmakers', 'share', 'her', 'convictions', 'and', 'assume', 'that', 'the', 'audience', 'will', ',', 'too', '.']
# ===================NLTK Tokenizer REMOVE STOP WORDS===================
# ['The', 'filmmakers', 'share', 'convictions', 'assume', 'audience', ',', '.']
# ===================NLTK Tokenizer REMOVED PUNCTUATION===================
# ['The', 'filmmakers', 'share', 'her', 'convictions', 'and', 'assume', 'that', 'the', 'audience', 'will', 'too']
# ===================NLTK Tokenizer REMOVED TAGS===================
# ['The', 'filmmakers', 'share', 'her', 'convictions', 'and', 'assume', 'that', 'the', 'audience', 'will', ',', 'too', '.']
# ===================NLTK Tokenizer REMOVED CHARS AND DIGITS===================
# ['The', 'filmmakers', 'share', 'her', 'convictions', 'and', 'assume', 'that', 'the', 'audience', 'will', 'too']
# ===================NLTK Tokenizer STEMMING APPLIED===================
# ['the', 'filmmak', 'share', 'her', 'convict', 'and', 'assum', 'that', 'the', 'audienc', 'will', ',', 'too', '.']
# ===================NLTK Tokenizer LEMMATIZATION APPLIED===================
# ['The', 'filmmaker', 'share', 'her', 'conviction', 'and', 'assume', 'that', 'the', 'audience', 'will', ',', 'too', '.']
# Which might be true, and not only because much of the audience is likely to consist of liberals.
# ===================NLTK Tokenizer===================
# ['Which', 'might', 'be', 'true', ',', 'and', 'not', 'only', 'because', 'much', 'of', 'the', 'audience', 'is', 'likely', 'to', 'consist', 'of', 'liberals', '.']
# ===================NLTK Word NGRAM Tokenizer 2 words===================
# ['Which might', 'might be', 'be true', 'true ,', ', and', 'and not', 'not only', 'only because', 'because much', 'much of', 'of the', 'the audience', 'audience is', 'is likely', 'likely to', 'to consist', 'consist of', 'of liberals', 'liberals .']
# ===================NLTK Word NGRAM Tokenizer 3 words===================
# ['Which might be', 'might be true', 'be true ,', 'true , and', ', and not', 'and not only', 'not only because', 'only because much', 'because much of', 'much of the', 'of the audience', 'the audience is', 'audience is likely', 'is likely to', 'likely to consist', 'to consist of', 'consist of liberals', 'of liberals .']
# ===================Phrase Machine===================
# ===================Rake===================
# ['true', 'much', 'might', 'likely', 'liberals', 'consist', 'audience']
# ===================NLTK Tokenizer===================
# ['Which', 'might', 'be', 'true', ',', 'and', 'not', 'only', 'because', 'much', 'of', 'the', 'audience', 'is', 'likely', 'to', 'consist', 'of', 'liberals', '.']
# ===================NLTK Tokenizer LOWER CASE===================
# ['which', 'might', 'be', 'true', ',', 'and', 'not', 'only', 'because', 'much', 'of', 'the', 'audience', 'is', 'likely', 'to', 'consist', 'of', 'liberals', '.']
# ===================NLTK Tokenizer REMOVE STOP WORDS===================
# ['Which', 'might', 'true', ',', 'much', 'audience', 'likely', 'consist', 'liberals', '.']
# ===================NLTK Tokenizer REMOVED PUNCTUATION===================
# ['Which', 'might', 'be', 'true', 'and', 'not', 'only', 'because', 'much', 'of', 'the', 'audience', 'is', 'likely', 'to', 'consist', 'of', 'liberals']
# ===================NLTK Tokenizer REMOVED TAGS===================
# ['Which', 'might', 'be', 'true', ',', 'and', 'not', 'only', 'because', 'much', 'of', 'the', 'audience', 'is', 'likely', 'to', 'consist', 'of', 'liberals', '.']
# ===================NLTK Tokenizer REMOVED CHARS AND DIGITS===================
# ['Which', 'might', 'be', 'true', 'and', 'not', 'only', 'because', 'much', 'of', 'the', 'audience', 'is', 'likely', 'to', 'consist', 'of', 'liberals']
# ===================NLTK Tokenizer STEMMING APPLIED===================
# ['which', 'might', 'be', 'true', ',', 'and', 'not', 'onli', 'becaus', 'much', 'of', 'the', 'audienc', 'is', 'like', 'to', 'consist', 'of', 'liber', '.']
# ===================NLTK Tokenizer LEMMATIZATION APPLIED===================
# ['Which', 'might', 'be', 'true', ',', 'and', 'not', 'only', 'because', 'much', 'of', 'the', 'audience', 'is', 'likely', 'to', 'consist', 'of', 'liberal', '.']
# Before she was named to the federal bench by Jimmy Carter in 1980, the future justice had argued a handful of important sex-discrimination cases in front of the Supreme Court.
# ===================NLTK Tokenizer===================
# ['Before', 'she', 'was', 'named', 'to', 'the', 'federal', 'bench', 'by', 'Jimmy', 'Carter', 'in', '1980', ',', 'the', 'future', 'justice', 'had', 'argued', 'a', 'handful', 'of', 'important', 'sex-discrimination', 'cases', 'in', 'front', 'of', 'the', 'Supreme', 'Court', '.']
# ===================NLTK Word NGRAM Tokenizer 2 words===================
# ['Before she', 'she was', 'was named', 'named to', 'to the', 'the federal', 'federal bench', 'bench by', 'by Jimmy', 'Jimmy Carter', 'Carter in', 'in 1980', '1980 ,', ', the', 'the future', 'future justice', 'justice had', 'had argued', 'argued a', 'a handful', 'handful of', 'of important', 'important sex-discrimination', 'sex-discrimination cases', 'cases in', 'in front', 'front of', 'of the', 'the Supreme', 'Supreme Court', 'Court .']
# ===================NLTK Word NGRAM Tokenizer 3 words===================
# ['Before she was', 'she was named', 'was named to', 'named to the', 'to the federal', 'the federal bench', 'federal bench by', 'bench by Jimmy', 'by Jimmy Carter', 'Jimmy Carter in', 'Carter in 1980', 'in 1980 ,', '1980 , the', ', the future', 'the future justice', 'future justice had', 'justice had argued', 'had argued a', 'argued a handful', 'a handful of', 'handful of important', 'of important sex-discrimination', 'important sex-discrimination cases', 'sex-discrimination cases in', 'cases in front', 'in front of', 'front of the', 'of the Supreme', 'the Supreme Court', 'Supreme Court .']
# ===================Phrase Machine===================
# federal bench
# federal bench by jimmy
# federal bench by jimmy carter
# bench by jimmy
# bench by jimmy carter
# jimmy carter
# future justice
# handful of important sex-discrimination
# handful of important sex-discrimination cases
# handful of important sex-discrimination cases in front
# important sex-discrimination
# important sex-discrimination cases
# important sex-discrimination cases in front
# important sex-discrimination cases in front of the supreme
# sex-discrimination cases
# sex-discrimination cases in front
# sex-discrimination cases in front of the supreme
# sex-discrimination cases in front of the supreme court
# cases in front
# cases in front of the supreme
# cases in front of the supreme court
# front of the supreme
# front of the supreme court
# supreme court
# ===================Rake===================
# ['supreme court', 'jimmy carter', 'important sex', 'future justice', 'federal bench', 'discrimination cases', 'named', 'handful', 'front', 'argued', '1980']
# ===================NLTK Tokenizer===================
# ['Before', 'she', 'was', 'named', 'to', 'the', 'federal', 'bench', 'by', 'Jimmy', 'Carter', 'in', '1980', ',', 'the', 'future', 'justice', 'had', 'argued', 'a', 'handful', 'of', 'important', 'sex-discrimination', 'cases', 'in', 'front', 'of', 'the', 'Supreme', 'Court', '.']
# ===================NLTK Tokenizer LOWER CASE===================
# ['before', 'she', 'was', 'named', 'to', 'the', 'federal', 'bench', 'by', 'jimmy', 'carter', 'in', '1980', ',', 'the', 'future', 'justice', 'had', 'argued', 'a', 'handful', 'of', 'important', 'sex-discrimination', 'cases', 'in', 'front', 'of', 'the', 'supreme', 'court', '.']
# ===================NLTK Tokenizer REMOVE STOP WORDS===================
# ['Before', 'named', 'federal', 'bench', 'Jimmy', 'Carter', '1980', ',', 'future', 'justice', 'argued', 'handful', 'important', 'sex-discrimination', 'cases', 'front', 'Supreme', 'Court', '.']
# ===================NLTK Tokenizer REMOVED PUNCTUATION===================
# ['Before', 'she', 'was', 'named', 'to', 'the', 'federal', 'bench', 'by', 'Jimmy', 'Carter', 'in', 'the', 'future', 'justice', 'had', 'argued', 'a', 'handful', 'of', 'important', 'sex', 'discrimination', 'cases', 'in', 'front', 'of', 'the', 'Supreme', 'Court']
# ===================NLTK Tokenizer REMOVED TAGS===================
# ['Before', 'she', 'was', 'named', 'to', 'the', 'federal', 'bench', 'by', 'Jimmy', 'Carter', 'in', '1980', ',', 'the', 'future', 'justice', 'had', 'argued', 'a', 'handful', 'of', 'important', 'sex-discrimination', 'cases', 'in', 'front', 'of', 'the', 'Supreme', 'Court', '.']
# ===================NLTK Tokenizer REMOVED CHARS AND DIGITS===================
# ['Before', 'she', 'was', 'named', 'to', 'the', 'federal', 'bench', 'by', 'Jimmy', 'Carter', 'in', 'the', 'future', 'justice', 'had', 'argued', 'a', 'handful', 'of', 'important', 'sex', 'discrimination', 'cases', 'in', 'front', 'of', 'the', 'Supreme', 'Court']
# ===================NLTK Tokenizer STEMMING APPLIED===================
# ['befor', 'she', 'wa', 'name', 'to', 'the', 'feder', 'bench', 'by', 'jimmi', 'carter', 'in', '1980', ',', 'the', 'futur', 'justic', 'had', 'argu', 'a', 'hand', 'of', 'import', 'sex-discrimin', 'case', 'in', 'front', 'of', 'the', 'suprem', 'court', '.']
# ===================NLTK Tokenizer LEMMATIZATION APPLIED===================
# ['Before', 'she', 'wa', 'named', 'to', 'the', 'federal', 'bench', 'by', 'Jimmy', 'Carter', 'in', '1980', ',', 'the', 'future', 'justice', 'had', 'argued', 'a', 'handful', 'of', 'important', 'sex-discrimination', 'case', 'in', 'front', 'of', 'the', 'Supreme', 'Court', '.']
# What linked these cases — she won five out of six — was the theory that the equal protection clause of the 14th Amendment should apply to women and could be used to remedy discrepancies in hiring, business practices and public policy.The idea that women are equal citizens — that barring them from certain jobs and educational opportunities and treating them as the social inferiors of men are unfair — may not seem especially controversial now.
# ===================NLTK Tokenizer===================
# ['What', 'linked', 'these', 'cases', '—', 'she', 'won', 'five', 'out', 'of', 'six', '—', 'was', 'the', 'theory', 'that', 'the', 'equal', 'protection', 'clause', 'of', 'the', '14th', 'Amendment', 'should', 'apply', 'to', 'women', 'and', 'could', 'be', 'used', 'to', 'remedy', 'discrepancies', 'in', 'hiring', ',', 'business', 'practices', 'and', 'public', 'policy.The', 'idea', 'that', 'women', 'are', 'equal', 'citizens', '—', 'that', 'barring', 'them', 'from', 'certain', 'jobs', 'and', 'educational', 'opportunities', 'and', 'treating', 'them', 'as', 'the', 'social', 'inferiors', 'of', 'men', 'are', 'unfair', '—', 'may', 'not', 'seem', 'especially', 'controversial', 'now', '.']
# ===================NLTK Word NGRAM Tokenizer 2 words===================
# ['What linked', 'linked these', 'these cases', 'cases —', '— she', 'she won', 'won five', 'five out', 'out of', 'of six', 'six —', '— was', 'was the', 'the theory', 'theory that', 'that the', 'the equal', 'equal protection', 'protection clause', 'clause of', 'of the', 'the 14th', '14th Amendment', 'Amendment should', 'should apply', 'apply to', 'to women', 'women and', 'and could', 'could be', 'be used', 'used to', 'to remedy', 'remedy discrepancies', 'discrepancies in', 'in hiring', 'hiring ,', ', business', 'business practices', 'practices and', 'and public', 'public policy.The', 'policy.The idea', 'idea that', 'that women', 'women are', 'are equal', 'equal citizens', 'citizens —', '— that', 'that barring', 'barring them', 'them from', 'from certain', 'certain jobs', 'jobs and', 'and educational', 'educational opportunities', 'opportunities and', 'and treating', 'treating them', 'them as', 'as the', 'the social', 'social inferiors', 'inferiors of', 'of men', 'men are', 'are unfair', 'unfair —', '— may', 'may not', 'not seem', 'seem especially', 'especially controversial', 'controversial now', 'now .']
# ===================NLTK Word NGRAM Tokenizer 3 words===================
# ['What linked these', 'linked these cases', 'these cases —', 'cases — she', '— she won', 'she won five', 'won five out', 'five out of', 'out of six', 'of six —', 'six — was', '— was the', 'was the theory', 'the theory that', 'theory that the', 'that the equal', 'the equal protection', 'equal protection clause', 'protection clause of', 'clause of the', 'of the 14th', 'the 14th Amendment', '14th Amendment should', 'Amendment should apply', 'should apply to', 'apply to women', 'to women and', 'women and could', 'and could be', 'could be used', 'be used to', 'used to remedy', 'to remedy discrepancies', 'remedy discrepancies in', 'discrepancies in hiring', 'in hiring ,', 'hiring , business', ', business practices', 'business practices and', 'practices and public', 'and public policy.The', 'public policy.The idea', 'policy.The idea that', 'idea that women', 'that women are', 'women are equal', 'are equal citizens', 'equal citizens —', 'citizens — that', '— that barring', 'that barring them', 'barring them from', 'them from certain', 'from certain jobs', 'certain jobs and', 'jobs and educational', 'and educational opportunities', 'educational opportunities and', 'opportunities and treating', 'and treating them', 'treating them as', 'them as the', 'as the social', 'the social inferiors', 'social inferiors of', 'inferiors of men', 'of men are', 'men are unfair', 'are unfair —', 'unfair — may', '— may not', 'may not seem', 'not seem especially', 'seem especially controversial', 'especially controversial now', 'controversial now .']
# ===================Phrase Machine===================
# six —
# theory that the equal protection
# theory that the equal protection clause
# equal protection
# equal protection clause
# equal protection clause of the 14th amendment
# protection clause
# protection clause of the 14th amendment
# clause of the 14th amendment
# 14th amendment
# discrepancies in hiring
# business practices
# public policy.the
# public policy.the idea
# public policy.the idea that women
# policy.the idea
# policy.the idea that women
# idea that women
# equal citizens
# certain jobs
# educational opportunities
# social inferiors
# social inferiors of men
# inferiors of men
# unfair —
# ===================Rake===================
# ['seem especially controversial', 'equal protection clause', 'unfair — may', 'equal citizens —', 'six —', 'cases —', 'social inferiors', 'remedy discrepancies', 'public policy', 'educational opportunities', 'certain jobs', 'business practices', '14th amendment', 'women', 'used', 'treating', 'theory', 'men', 'linked', 'idea', 'hiring', 'five', 'could', 'barring', 'apply']
# ===================NLTK Tokenizer===================
# ['What', 'linked', 'these', 'cases', '—', 'she', 'won', 'five', 'out', 'of', 'six', '—', 'was', 'the', 'theory', 'that', 'the', 'equal', 'protection', 'clause', 'of', 'the', '14th', 'Amendment', 'should', 'apply', 'to', 'women', 'and', 'could', 'be', 'used', 'to', 'remedy', 'discrepancies', 'in', 'hiring', ',', 'business', 'practices', 'and', 'public', 'policy.The', 'idea', 'that', 'women', 'are', 'equal', 'citizens', '—', 'that', 'barring', 'them', 'from', 'certain', 'jobs', 'and', 'educational', 'opportunities', 'and', 'treating', 'them', 'as', 'the', 'social', 'inferiors', 'of', 'men', 'are', 'unfair', '—', 'may', 'not', 'seem', 'especially', 'controversial', 'now', '.']
# ===================NLTK Tokenizer LOWER CASE===================
# ['what', 'linked', 'these', 'cases', '—', 'she', 'won', 'five', 'out', 'of', 'six', '—', 'was', 'the', 'theory', 'that', 'the', 'equal', 'protection', 'clause', 'of', 'the', '14th', 'amendment', 'should', 'apply', 'to', 'women', 'and', 'could', 'be', 'used', 'to', 'remedy', 'discrepancies', 'in', 'hiring', ',', 'business', 'practices', 'and', 'public', 'policy.the', 'idea', 'that', 'women', 'are', 'equal', 'citizens', '—', 'that', 'barring', 'them', 'from', 'certain', 'jobs', 'and', 'educational', 'opportunities', 'and', 'treating', 'them', 'as', 'the', 'social', 'inferiors', 'of', 'men', 'are', 'unfair', '—', 'may', 'not', 'seem', 'especially', 'controversial', 'now', '.']
# ===================NLTK Tokenizer REMOVE STOP WORDS===================
# ['What', 'linked', 'cases', '—', 'five', 'six', '—', 'theory', 'equal', 'protection', 'clause', '14th', 'Amendment', 'apply', 'women', 'could', 'used', 'remedy', 'discrepancies', 'hiring', ',', 'business', 'practices', 'public', 'policy.The', 'idea', 'women', 'equal', 'citizens', '—', 'barring', 'certain', 'jobs', 'educational', 'opportunities', 'treating', 'social', 'inferiors', 'men', 'unfair', '—', 'may', 'seem', 'especially', 'controversial', '.']
# ===================NLTK Tokenizer REMOVED PUNCTUATION===================
# ['What', 'linked', 'these', 'cases', 'she', 'won', 'five', 'out', 'of', 'six', 'was', 'the', 'theory', 'that', 'the', 'equal', 'protection', 'clause', 'of', 'the', 'th', 'Amendment', 'should', 'apply', 'to', 'women', 'and', 'could', 'be', 'used', 'to', 'remedy', 'discrepancies', 'in', 'hiring', 'business', 'practices', 'and', 'public', 'policy', 'The', 'idea', 'that', 'women', 'are', 'equal', 'citizens', 'that', 'barring', 'them', 'from', 'certain', 'jobs', 'and', 'educational', 'opportunities', 'and', 'treating', 'them', 'as', 'the', 'social', 'inferiors', 'of', 'men', 'are', 'unfair', 'may', 'not', 'seem', 'especially', 'controversial', 'now']
# ===================NLTK Tokenizer REMOVED TAGS===================
# ['What', 'linked', 'these', 'cases', '—', 'she', 'won', 'five', 'out', 'of', 'six', '—', 'was', 'the', 'theory', 'that', 'the', 'equal', 'protection', 'clause', 'of', 'the', '14th', 'Amendment', 'should', 'apply', 'to', 'women', 'and', 'could', 'be', 'used', 'to', 'remedy', 'discrepancies', 'in', 'hiring', ',', 'business', 'practices', 'and', 'public', 'policy.The', 'idea', 'that', 'women', 'are', 'equal', 'citizens', '—', 'that', 'barring', 'them', 'from', 'certain', 'jobs', 'and', 'educational', 'opportunities', 'and', 'treating', 'them', 'as', 'the', 'social', 'inferiors', 'of', 'men', 'are', 'unfair', '—', 'may', 'not', 'seem', 'especially', 'controversial', 'now', '.']
# ===================NLTK Tokenizer REMOVED CHARS AND DIGITS===================
# ['What', 'linked', 'these', 'cases', 'she', 'won', 'five', 'out', 'of', 'six', 'was', 'the', 'theory', 'that', 'the', 'equal', 'protection', 'clause', 'of', 'the', 'th', 'Amendment', 'should', 'apply', 'to', 'women', 'and', 'could', 'be', 'used', 'to', 'remedy', 'discrepancies', 'in', 'hiring', 'business', 'practices', 'and', 'public', 'policy', 'The', 'idea', 'that', 'women', 'are', 'equal', 'citizens', 'that', 'barring', 'them', 'from', 'certain', 'jobs', 'and', 'educational', 'opportunities', 'and', 'treating', 'them', 'as', 'the', 'social', 'inferiors', 'of', 'men', 'are', 'unfair', 'may', 'not', 'seem', 'especially', 'controversial', 'now']
# ===================NLTK Tokenizer STEMMING APPLIED===================
# ['what', 'link', 'these', 'case', '—', 'she', 'won', 'five', 'out', 'of', 'six', '—', 'wa', 'the', 'theori', 'that', 'the', 'equal', 'protect', 'claus', 'of', 'the', '14th', 'amend', 'should', 'appli', 'to', 'women', 'and', 'could', 'be', 'use', 'to', 'remedi', 'discrep', 'in', 'hire', ',', 'busi', 'practic', 'and', 'public', 'policy.th', 'idea', 'that', 'women', 'are', 'equal', 'citizen', '—', 'that', 'bar', 'them', 'from', 'certain', 'job', 'and', 'educ', 'opportun', 'and', 'treat', 'them', 'as', 'the', 'social', 'inferior', 'of', 'men', 'are', 'unfair', '—', 'may', 'not', 'seem', 'especi', 'controversi', 'now', '.']
# ===================NLTK Tokenizer LEMMATIZATION APPLIED===================
# ['What', 'linked', 'these', 'case', '—', 'she', 'won', 'five', 'out', 'of', 'six', '—', 'wa', 'the', 'theory', 'that', 'the', 'equal', 'protection', 'clause', 'of', 'the', '14th', 'Amendment', 'should', 'apply', 'to', 'woman', 'and', 'could', 'be', 'used', 'to', 'remedy', 'discrepancy', 'in', 'hiring', ',', 'business', 'practice', 'and', 'public', 'policy.The', 'idea', 'that', 'woman', 'are', 'equal', 'citizen', '—', 'that', 'barring', 'them', 'from', 'certain', 'job', 'and', 'educational', 'opportunity', 'and', 'treating', 'them', 'a', 'the', 'social', 'inferior', 'of', 'men', 'are', 'unfair', '—', 'may', 'not', 'seem', 'especially', 'controversial', 'now', '.']
# “RBG” uses Justice Ginsburg’s own experiences to emphasize how different things were not so long ago.
# ===================NLTK Tokenizer===================
# ['“', 'RBG', '”', 'uses', 'Justice', 'Ginsburg', '’', 's', 'own', 'experiences', 'to', 'emphasize', 'how', 'different', 'things', 'were', 'not', 'so', 'long', 'ago', '.']
# ===================NLTK Word NGRAM Tokenizer 2 words===================
# ['“ RBG', 'RBG ”', '” uses', 'uses Justice', 'Justice Ginsburg', 'Ginsburg ’', '’ s', 's own', 'own experiences', 'experiences to', 'to emphasize', 'emphasize how', 'how different', 'different things', 'things were', 'were not', 'not so', 'so long', 'long ago', 'ago .']
# ===================NLTK Word NGRAM Tokenizer 3 words===================
# ['“ RBG ”', 'RBG ” uses', '” uses Justice', 'uses Justice Ginsburg', 'Justice Ginsburg ’', 'Ginsburg ’ s', '’ s own', 's own experiences', 'own experiences to', 'experiences to emphasize', 'to emphasize how', 'emphasize how different', 'how different things', 'different things were', 'things were not', 'were not so', 'not so long', 'so long ago', 'long ago .']
# ===================Phrase Machine===================
# “rbg” uses
# “rbg” uses justice
# “rbg” uses justice ginsburg’s
# “rbg” uses justice ginsburg’s own experiences
# ...
# ===================NLTK Word NGRAM Tokenizer 2 words===================
# ['It also', 'also shows', 'shows why', 'why she', 'she has', 'has become', 'become such', 'such an', 'an inspiration', 'inspiration for', 'for younger', 'younger feminists', 'feminists ,', ', like', 'like Irin', 'Irin Carmon', 'Carmon and', 'and Shana', 'Shana Knizhnik', 'Knizhnik ,', ', whose', 'whose 2015', '2015 book', 'book “', '“ Notorious', 'Notorious RBG', 'RBG :', ': The', 'The Life', 'Life and', 'and Times', 'Times of', 'of Ruth', 'Ruth Bader', 'Bader Ginsburg', 'Ginsburg ”', '” helped', 'helped created', 'created the', 'the contemporary', 'contemporary image', 'image of', 'of a', 'a fierce', 'fierce ,', ', uncompromising', 'uncompromising and', 'and gracious', 'gracious champion', 'champion of', 'of women', 'women ’', '’ s', 's rights.That', 'rights.That those', 'those rights', 'rights are', 'are in', 'in a', 'a new', 'new phase', 'phase of', 'of embattlement', 'embattlement goes', 'goes without', 'without saying', 'saying .']
# ===================NLTK Word NGRAM Tokenizer 3 words===================
# ['It also shows', 'also shows why', 'shows why she', 'why she has', 'she has become', 'has become such', 'become such an', 'such an inspiration', 'an inspiration for', 'inspiration for younger', 'for younger feminists', 'younger feminists ,', 'feminists , like', ', like Irin', 'like Irin Carmon', 'Irin Carmon and', 'Carmon and Shana', 'and Shana Knizhnik', 'Shana Knizhnik ,', 'Knizhnik , whose', ', whose 2015', 'whose 2015 book', '2015 book “', 'book “ Notorious', '“ Notorious RBG', 'Notorious RBG :', 'RBG : The', ': The Life', 'The Life and', 'Life and Times', 'and Times of', 'Times of Ruth', 'of Ruth Bader', 'Ruth Bader Ginsburg', 'Bader Ginsburg ”', 'Ginsburg ” helped', '” helped created', 'helped created the', 'created the contemporary', 'the contemporary image', 'contemporary image of', 'image of a', 'of a fierce', 'a fierce ,', 'fierce , uncompromising', ', uncompromising and', 'uncompromising and gracious', 'and gracious champion', 'gracious champion of', 'champion of women', 'of women ’', 'women ’ s', '’ s rights.That', 's rights.That those', 'rights.That those rights', 'those rights are', 'rights are in', 'are in a', 'in a new', 'a new phase', 'new phase of', 'phase of embattlement', 'of embattlement goes', 'embattlement goes without', 'goes without saying', 'without saying .']
# ===================Phrase Machine===================
# inspiration for younger feminists
# younger feminists
# irin carmon
# shana knizhnik
# 2015 book
# 2015 book “notorious rbg
# book “notorious rbg
# “notorious rbg
# times of ruth
# times of ruth bader
# times of ruth bader ginsburg”
# ruth bader
# ruth bader ginsburg”
# bader ginsburg”
# contemporary image
# gracious champion
# gracious champion of women’s
# champion of women’s
# new phase
# new phase of embattlement
# phase of embattlement
# ===================Rake===================
# ['whose 2015 book “ notorious rbg', 'ruth bader ginsburg ” helped created', 'embattlement goes without saying', 'like irin carmon', 'younger feminists', 'women ’', 'shana knizhnik', 'new phase', 'gracious champion', 'contemporary image', 'also shows', 'uncompromising', 'times', 'rights', 'life', 'inspiration', 'fierce', 'become']
# ===================NLTK Tokenizer===================
# ['It', 'also', 'shows', 'why', 'she', 'has', 'become', 'such', 'an', 'inspiration', 'for', 'younger', 'feminists', ',', 'like', 'Irin', 'Carmon', 'and', 'Shana', 'Knizhnik', ',', 'whose', '2015', 'book', '“', 'Notorious', 'RBG', ':', 'The', 'Life', 'and', 'Times', 'of', 'Ruth', 'Bader', 'Ginsburg', '”', 'helped', 'created', 'the', 'contemporary', 'image', 'of', 'a', 'fierce', ',', 'uncompromising', 'and', 'gracious', 'champion', 'of', 'women', '’', 's', 'rights.That', 'those', 'rights', 'are', 'in', 'a', 'new', 'phase', 'of', 'embattlement', 'goes', 'without', 'saying', '.']
# ===================NLTK Tokenizer LOWER CASE===================
# ['it', 'also', 'shows', 'why', 'she', 'has', 'become', 'such', 'an', 'inspiration', 'for', 'younger', 'feminists', ',', 'like', 'irin', 'carmon', 'and', 'shana', 'knizhnik', ',', 'whose', '2015', 'book', '“', 'notorious', 'rbg', ':', 'the', 'life', 'and', 'times', 'of', 'ruth', 'bader', 'ginsburg', '”', 'helped', 'created', 'the', 'contemporary', 'image', 'of', 'a', 'fierce', ',', 'uncompromising', 'and', 'gracious', 'champion', 'of', 'women', '’', 's', 'rights.that', 'those', 'rights', 'are', 'in', 'a', 'new', 'phase', 'of', 'embattlement', 'goes', 'without', 'saying', '.']
# ===================NLTK Tokenizer REMOVE STOP WORDS===================
# ['It', 'also', 'shows', 'become', 'inspiration', 'younger', 'feminists', ',', 'like', 'Irin', 'Carmon', 'Shana', 'Knizhnik', ',', 'whose', '2015', 'book', '“', 'Notorious', 'RBG', ':', 'The', 'Life', 'Times', 'Ruth', 'Bader', 'Ginsburg', '”', 'helped', 'created', 'contemporary', 'image', 'fierce', ',', 'uncompromising', 'gracious', 'champion', 'women', '’', 'rights.That', 'rights', 'new', 'phase', 'embattlement', 'goes', 'without', 'saying', '.']
# ===================NLTK Tokenizer REMOVED PUNCTUATION===================
# ['It', 'also', 'shows', 'why', 'she', 'has', 'become', 'such', 'an', 'inspiration', 'for', 'younger', 'feminists', 'like', 'Irin', 'Carmon', 'and', 'Shana', 'Knizhnik', 'whose', 'book', 'Notorious', 'RBG', 'The', 'Life', 'and', 'Times', 'of', 'Ruth', 'Bader', 'Ginsburg', 'helped', 'created', 'the', 'contemporary', 'image', 'of', 'a', 'fierce', 'uncompromising', 'and', 'gracious', 'champion', 'of', 'women', 's', 'rights', 'That', 'those', 'rights', 'are', 'in', 'a', 'new', 'phase', 'of', 'embattlement', 'goes', 'without', 'saying']
# ===================NLTK Tokenizer REMOVED TAGS===================
# ['It', 'also', 'shows', 'why', 'she', 'has', 'become', 'such', 'an', 'inspiration', 'for', 'younger', 'feminists', ',', 'like', 'Irin', 'Carmon', 'and', 'Shana', 'Knizhnik', ',', 'whose', '2015', 'book', '“', 'Notorious', 'RBG', ':', 'The', 'Life', 'and', 'Times', 'of', 'Ruth', 'Bader', 'Ginsburg', '”', 'helped', 'created', 'the', 'contemporary', 'image', 'of', 'a', 'fierce', ',', 'uncompromising', 'and', 'gracious', 'champion', 'of', 'women', '’', 's', 'rights.That', 'those', 'rights', 'are', 'in', 'a', 'new', 'phase', 'of', 'embattlement', 'goes', 'without', 'saying', '.']
# ===================NLTK Tokenizer REMOVED CHARS AND DIGITS===================
# ['It', 'also', 'shows', 'why', 'she', 'has', 'become', 'such', 'an', 'inspiration', 'for', 'younger', 'feminists', 'like', 'Irin', 'Carmon', 'and', 'Shana', 'Knizhnik', 'whose', 'book', 'Notorious', 'RBG', 'The', 'Life', 'and', 'Times', 'of', 'Ruth', 'Bader', 'Ginsburg', 'helped', 'created', 'the', 'contemporary', 'image', 'of', 'a', 'fierce', 'uncompromising', 'and', 'gracious', 'champion', 'of', 'women', 's', 'rights', 'That', 'those', 'rights', 'are', 'in', 'a', 'new', 'phase', 'of', 'embattlement', 'goes', 'without', 'saying']
# ===================NLTK Tokenizer STEMMING APPLIED===================
# ['It', 'also', 'show', 'whi', 'she', 'ha', 'becom', 'such', 'an', 'inspir', 'for', 'younger', 'feminist', ',', 'like', 'irin', 'carmon', 'and', 'shana', 'knizhnik', ',', 'whose', '2015', 'book', '“', 'notori', 'rbg', ':', 'the', 'life', 'and', 'time', 'of', 'ruth', 'bader', 'ginsburg', '”', 'help', 'creat', 'the', 'contemporari', 'imag', 'of', 'a', 'fierc', ',', 'uncompromis', 'and', 'graciou', 'champion', 'of', 'women', '’', 's', 'rights.that', 'those', 'right', 'are', 'in', 'a', 'new', 'phase', 'of', 'embattl', 'goe', 'without', 'say', '.']
# ===================NLTK Tokenizer LEMMATIZATION APPLIED===================
# ['It', 'also', 'show', 'why', 'she', 'ha', 'become', 'such', 'an', 'inspiration', 'for', 'younger', 'feminist', ',', 'like', 'Irin', 'Carmon', 'and', 'Shana', 'Knizhnik', ',', 'whose', '2015', 'book', '“', 'Notorious', 'RBG', ':', 'The', 'Life', 'and', 'Times', 'of', 'Ruth', 'Bader', 'Ginsburg', '”', 'helped', 'created', 'the', 'contemporary', 'image', 'of', 'a', 'fierce', ',', 'uncompromising', 'and', 'gracious', 'champion', 'of', 'woman', '’', 's', 'rights.That', 'those', 'right', 'are', 'in', 'a', 'new', 'phase', 'of', 'embattlement', 'go', 'without', 'saying', '.']
# The movie’s touch is light and its spirit buoyant, but there is no mistaking its seriousness or its passion.
# ===================NLTK Tokenizer===================
# ['The', 'movie', '’', 's', 'touch', 'is', 'light', 'and', 'its', 'spirit', 'buoyant', ',', 'but', 'there', 'is', 'no', 'mistaking', 'its', 'seriousness', 'or', 'its', 'passion', '.']
# ===================NLTK Word NGRAM Tokenizer 2 words===================
# ['The movie', 'movie ’', '’ s', 's touch', 'touch is', 'is light', 'light and', 'and its', 'its spirit', 'spirit buoyant', 'buoyant ,', ', but', 'but there', 'there is', 'is no', 'no mistaking', 'mistaking its', 'its seriousness', 'seriousness or', 'or its', 'its passion', 'passion .']
# ===================NLTK Word NGRAM Tokenizer 3 words===================
# ['The movie ’', 'movie ’ s', '’ s touch', 's touch is', 'touch is light', 'is light and', 'light and its', 'and its spirit', 'its spirit buoyant', 'spirit buoyant ,', 'buoyant , but', ', but there', 'but there is', 'there is no', 'is no mistaking', 'no mistaking its', 'mistaking its seriousness', 'its seriousness or', 'seriousness or its', 'or its passion', 'its passion .']
# ===================Phrase Machine===================
# movie’s touch
# spirit buoyant
# ===================Rake===================
# ['spirit buoyant', 'movie ’', 'touch', 'seriousness', 'passion', 'mistaking', 'light']
# ===================NLTK Tokenizer===================
# ['The', 'movie', '’', 's', 'touch', 'is', 'light', 'and', 'its', 'spirit', 'buoyant', ',', 'but', 'there', 'is', 'no', 'mistaking', 'its', 'seriousness', 'or', 'its', 'passion', '.']
# ===================NLTK Tokenizer LOWER CASE===================
# ['the', 'movie', '’', 's', 'touch', 'is', 'light', 'and', 'its', 'spirit', 'buoyant', ',', 'but', 'there', 'is', 'no', 'mistaking', 'its', 'seriousness', 'or', 'its', 'passion', '.']
# ===================NLTK Tokenizer REMOVE STOP WORDS===================
# ['The', 'movie', '’', 'touch', 'light', 'spirit', 'buoyant', ',', 'mistaking', 'seriousness', 'passion', '.']
# ===================NLTK Tokenizer REMOVED PUNCTUATION===================
# ['The', 'movie', 's', 'touch', 'is', 'light', 'and', 'its', 'spirit', 'buoyant', 'but', 'there', 'is', 'no', 'mistaking', 'its', 'seriousness', 'or', 'its', 'passion']
# ===================NLTK Tokenizer REMOVED TAGS===================
# ['The', 'movie', '’', 's', 'touch', 'is', 'light', 'and', 'its', 'spirit', 'buoyant', ',', 'but', 'there', 'is', 'no', 'mistaking', 'its', 'seriousness', 'or', 'its', 'passion', '.']
# ===================NLTK Tokenizer REMOVED CHARS AND DIGITS===================
# ['The', 'movie', 's', 'touch', 'is', 'light', 'and', 'its', 'spirit', 'buoyant', 'but', 'there', 'is', 'no', 'mistaking', 'its', 'seriousness', 'or', 'its', 'passion']
# ===================NLTK Tokenizer STEMMING APPLIED===================
# ['the', 'movi', '’', 's', 'touch', 'is', 'light', 'and', 'it', 'spirit', 'buoyant', ',', 'but', 'there', 'is', 'no', 'mistak', 'it', 'serious', 'or', 'it', 'passion', '.']
# ===================NLTK Tokenizer LEMMATIZATION APPLIED===================
# ['The', 'movie', '’', 's', 'touch', 'is', 'light', 'and', 'it', 'spirit', 'buoyant', ',', 'but', 'there', 'is', 'no', 'mistaking', 'it', 'seriousness', 'or', 'it', 'passion', '.']
# Those qualities resonate powerfully in the dissents that may prove to be Justice Ginsburg’s most enduring legacy, and “RBG” is, above all, a tribute to her voice.
# ===================NLTK Tokenizer===================
# ['Those', 'qualities', 'resonate', 'powerfully', 'in', 'the', 'dissents', 'that', 'may', 'prove', 'to', 'be', 'Justice', 'Ginsburg', '’', 's', 'most', 'enduring', 'legacy', ',', 'and', '“', 'RBG', '”', 'is', ',', 'above', 'all', ',', 'a', 'tribute', 'to', 'her', 'voice', '.']
# ===================NLTK Word NGRAM Tokenizer 2 words===================
# ['Those qualities', 'qualities resonate', 'resonate powerfully', 'powerfully in', 'in the', 'the dissents', 'dissents that', 'that may', 'may prove', 'prove to', 'to be', 'be Justice', 'Justice Ginsburg', 'Ginsburg ’', '’ s', 's most', 'most enduring', 'enduring legacy', 'legacy ,', ', and', 'and “', '“ RBG', 'RBG ”', '” is', 'is ,', ', above', 'above all', 'all ,', ', a', 'a tribute', 'tribute to', 'to her', 'her voice', 'voice .']
# ===================NLTK Word NGRAM Tokenizer 3 words===================
# ['Those qualities resonate', 'qualities resonate powerfully', 'resonate powerfully in', 'powerfully in the', 'in the dissents', 'the dissents that', 'dissents that may', 'that may prove', 'may prove to', 'prove to be', 'to be Justice', 'be Justice Ginsburg', 'Justice Ginsburg ’', 'Ginsburg ’ s', '’ s most', 's most enduring', 'most enduring legacy', 'enduring legacy ,', 'legacy , and', ', and “', 'and “ RBG', '“ RBG ”', 'RBG ” is', '” is ,', 'is , above', ', above all', 'above all ,', 'all , a', ', a tribute', 'a tribute to', 'tribute to her', 'to her voice', 'her voice .']
# ===================Phrase Machine===================
# justice ginsburg’s
# ===================Rake===================
# ['“ rbg ”', 'qualities resonate powerfully', 'justice ginsburg ’', 'may prove', 'enduring legacy', 'voice', 'tribute', 'dissents']
# ===================NLTK Tokenizer===================
# ['Those', 'qualities', 'resonate', 'powerfully', 'in', 'the', 'dissents', 'that', 'may', 'prove', 'to', 'be', 'Justice', 'Ginsburg', '’', 's', 'most', 'enduring', 'legacy', ',', 'and', '“', 'RBG', '”', 'is', ',', 'above', 'all', ',', 'a', 'tribute', 'to', 'her', 'voice', '.']
# ===================NLTK Tokenizer LOWER CASE===================
# ['those', 'qualities', 'resonate', 'powerfully', 'in', 'the', 'dissents', 'that', 'may', 'prove', 'to', 'be', 'justice', 'ginsburg', '’', 's', 'most', 'enduring', 'legacy', ',', 'and', '“', 'rbg', '”', 'is', ',', 'above', 'all', ',', 'a', 'tribute', 'to', 'her', 'voice', '.']
# ===================NLTK Tokenizer REMOVE STOP WORDS===================
# ['Those', 'qualities', 'resonate', 'powerfully', 'dissents', 'may', 'prove', 'Justice', 'Ginsburg', '’', 'enduring', 'legacy', ',', '“', 'RBG', '”', ',', ',', 'tribute', 'voice', '.']
# ===================NLTK Tokenizer REMOVED PUNCTUATION===================
# ['Those', 'qualities', 'resonate', 'powerfully', 'in', 'the', 'dissents', 'that', 'may', 'prove', 'to', 'be', 'Justice', 'Ginsburg', 's', 'most', 'enduring', 'legacy', 'and', 'RBG', 'is', 'above', 'all', 'a', 'tribute', 'to', 'her', 'voice']
# ===================NLTK Tokenizer REMOVED TAGS===================
# ['Those', 'qualities', 'resonate', 'powerfully', 'in', 'the', 'dissents', 'that', 'may', 'prove', 'to', 'be', 'Justice', 'Ginsburg', '’', 's', 'most', 'enduring', 'legacy', ',', 'and', '“', 'RBG', '”', 'is', ',', 'above', 'all', ',', 'a', 'tribute', 'to', 'her', 'voice', '.']
# ===================NLTK Tokenizer REMOVED CHARS AND DIGITS===================
# ['Those', 'qualities', 'resonate', 'powerfully', 'in', 'the', 'dissents', 'that', 'may', 'prove', 'to', 'be', 'Justice', 'Ginsburg', 's', 'most', 'enduring', 'legacy', 'and', 'RBG', 'is', 'above', 'all', 'a', 'tribute', 'to', 'her', 'voice']
# ===================NLTK Tokenizer STEMMING APPLIED===================
# ['those', 'qualiti', 'reson', 'power', 'in', 'the', 'dissent', 'that', 'may', 'prove', 'to', 'be', 'justic', 'ginsburg', '’', 's', 'most', 'endur', 'legaci', ',', 'and', '“', 'rbg', '”', 'is', ',', 'abov', 'all', ',', 'a', 'tribut', 'to', 'her', 'voic', '.']
# ===================NLTK Tokenizer LEMMATIZATION APPLIED===================
# ['Those', 'quality', 'resonate', 'powerfully', 'in', 'the', 'dissent', 'that', 'may', 'prove', 'to', 'be', 'Justice', 'Ginsburg', '’', 's', 'most', 'enduring', 'legacy', ',', 'and', '“', 'RBG', '”', 'is', ',', 'above', 'all', ',', 'a', 'tribute', 'to', 'her', 'voice', '.']

# %%
#Explore different extractors and difference preprocessing techniques
all_terms=[]
for sentence in sentences:
    print(sentence)
    #pick your favorite term extractor
    all_terms = all_terms +run_rake(sentence)
#get the frequency distribution across the terms
fd=get_freq_dist(all_terms)
fd
# Out:
# Ruth Bader Ginsburg was the second woman appointed to the United States Supreme Court, but she’s probably the first justice to become a full-fledged pop-cultural phenomenon.
# “RBG,” a loving and informative documentary portrait of Justice Ginsburg during her 85th year on earth and her 25th on the bench, is both evidence of this status and a partial explanation of how it came about.Directed by Betsy West and Julie Cohen, the film is a jaunty assemblage of interviews, public appearances and archival material, organized to illuminate its subject’s temperament and her accomplishments so far.
# Though it begins with audio snippets of Justice Ginsburg’s right-wing detractors — who see her as a “demon,” a “devil” and a threat to America — “RBG” takes a pointedly high road through recent political controversies.
# Its celebration of Justice Ginsburg’s record of progressive activism and jurisprudence is partisan but not especially polemical.
# The filmmakers share her convictions and assume that the audience will, too.
# Which might be true, and not only because much of the audience is likely to consist of liberals.
# Before she was named to the federal bench by Jimmy Carter in 1980, the future justice had argued a handful of important sex-discrimination cases in front of the Supreme Court.
# What linked these cases — she won five out of six — was the theory that the equal protection clause of the 14th Amendment should apply to women and could be used to remedy discrepancies in hiring, business practices and public policy.The idea that women are equal citizens — that barring them from certain jobs and educational opportunities and treating them as the social inferiors of men are unfair — may not seem especially controversial now.
# “RBG” uses Justice Ginsburg’s own experiences to emphasize how different things were not so long ago.
# At Harvard Law School, she was one of nine women in a class of hundreds, and was asked by the dean (as all the women were) why she thought she deserved to take what should have been a man’s place.The biographical part of “RBG” tells a story that is both typical and exceptional.
# It’s a reminder that the upward striving of first- and second-generation Jewish immigrants in the middle decades of the 20th century was accompanied by fervent political idealism.
# Justice Ginsburg’s career was marked by intense intellectual ambition and also by a determination to use the law as an instrument of change.The film also chronicles her marriage to Martin Ginsburg.
# They met as undergraduates at Cornell, and for the next 63 years, Mr. Ginsburg (who died in 2010) was his wife’s tireless supporter and champion, a man whose commitment to domestic egalitarianism was extraordinary in his time and far from common today.
# As their friends and children explain — and as Mr. Ginsburg, a New York tax lawyer, often said himself — he was responsible for cooking meals and cracking jokes while she was making history.
# He also, when Byron White retired from the Supreme Court, made sure that her name was high on President Clinton’s list of candidates.It would be fascinating to learn more about that campaign, and also to have a finer-grained sense of the institutional and interpersonal dynamics of the court over the past quarter-century.
# But “RBG” reasonably chooses to focus on Justice Ginsburg herself, and relishes every moment of her company.
# It also shows why she has become such an inspiration for younger feminists, like Irin Carmon and Shana Knizhnik, whose 2015 book “Notorious RBG: The Life and Times of Ruth Bader Ginsburg” helped created the contemporary image of a fierce, uncompromising and gracious champion of women’s rights.That those rights are in a new phase of embattlement goes without saying.
# The movie’s touch is light and its spirit buoyant, but there is no mistaking its seriousness or its passion.
# Those qualities resonate powerfully in the dissents that may prove to be Justice Ginsburg’s most enduring legacy, and “RBG” is, above all, a tribute to her voice.
# FreqDist({'justice ginsburg ’': 4, '’': 2, 'become': 2, 'justice ginsburg': 2, 'far': 2, 'audience': 2, 'supreme court': 2, 'women': 2, 'also': 2, 'mr': 2, ...})
