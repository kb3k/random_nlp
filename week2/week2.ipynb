# %%
import pandas as pd

# %%
path = "/Users/kerry/Projects/msds453/assign0/toxicAvenger/"

# %%
reviews = pd.read_csv(path+"KerryKurcz_MovieReview.csv")
meta = pd.read_csv(path+"KerryKurcz_MetaData.csv")

# %%
reviews.head()
# Out:
#                 FileName                                        MovieReview
# 0  KKN_Doc1_ToxicAvenger  This film believe or not is one of my favorate...
# 1  KKN_Doc2_ToxicAvenger  When I was a teenager, the only available plac...
# 2  KKN_Doc3_ToxicAvenger  I've never seen a Troma film before but I do r...
# 3  KKN_Doc4_ToxicAvenger  Toxic Avenger 21st Anniversary Ed. 2 Disc Set ...
# 4  KKN_Doc5_ToxicAvenger  The Toxic Avenger is an excellent and hilariou...

# %%
# transposed - not needed, but interesante
df0 = pd.DataFrame([f"Document {idx}" for idx in range(1, 11)], columns = ["Document"])
#df0.head(30)

# %%
df = pd.DataFrame(index=[f"Term {idx}" for idx in range(1, 21)], columns = [f"Document {idx}" for idx in range(1, 11)])

# %%
df
# Out:
#         Document 1 Document 2 Document 3 Document 4 Document 5 Document 6  \
# Term 1         NaN        NaN        NaN        NaN        NaN        NaN
# Term 2         NaN        NaN        NaN        NaN        NaN        NaN
# Term 3         NaN        NaN        NaN        NaN        NaN        NaN
# Term 4         NaN        NaN        NaN        NaN        NaN        NaN
# Term 5         NaN        NaN        NaN        NaN        NaN        NaN
# Term 6         NaN        NaN        NaN        NaN        NaN        NaN
# Term 7         NaN        NaN        NaN        NaN        NaN        NaN
# Term 8         NaN        NaN        NaN        NaN        NaN        NaN
# Term 9         NaN        NaN        NaN        NaN        NaN        NaN
# Term 10        NaN        NaN        NaN        NaN        NaN        NaN
# Term 11        NaN        NaN        NaN        NaN        NaN        NaN
# Term 12        NaN        NaN        NaN        NaN        NaN        NaN
# Term 13        NaN        NaN        NaN        NaN        NaN        NaN
# Term 14        NaN        NaN        NaN        NaN        NaN        NaN
# Term 15        NaN        NaN        NaN        NaN        NaN        NaN
# Term 16        NaN        NaN        NaN        NaN        NaN        NaN
# Term 17        NaN        NaN        NaN        NaN        NaN        NaN
# Term 18        NaN        NaN        NaN        NaN        NaN        NaN
# Term 19        NaN        NaN        NaN        NaN        NaN        NaN
# Term 20        NaN        NaN        NaN        NaN        NaN        NaN
#
#         Document 7 Document 8 Document 9 Document 10
# Term 1         NaN        NaN        NaN         NaN
# Term 2         NaN        NaN        NaN         NaN
# Term 3         NaN        NaN        NaN         NaN
# Term 4         NaN        NaN        NaN         NaN
# Term 5         NaN        NaN        NaN         NaN
# Term 6         NaN        NaN        NaN         NaN
# Term 7         NaN        NaN        NaN         NaN
# Term 8         NaN        NaN        NaN         NaN
# Term 9         NaN        NaN        NaN         NaN
# Term 10        NaN        NaN        NaN         NaN
# Term 11        NaN        NaN        NaN         NaN
# Term 12        NaN        NaN        NaN         NaN
# Term 13        NaN        NaN        NaN         NaN
# Term 14        NaN        NaN        NaN         NaN
# Term 15        NaN        NaN        NaN         NaN
# Term 16        NaN        NaN        NaN         NaN
# Term 17        NaN        NaN        NaN         NaN
# Term 18        NaN        NaN        NaN         NaN
# Term 19        NaN        NaN        NaN         NaN
# Term 20        NaN        NaN        NaN         NaN

# %%
# what are the terms *thinking face*

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import string
import re

# %%
stop_words = stopwords.words('english')

def clean_please(some_data):
    """
    """
    re_punk = re.compile('[%s]' % re.escape(string.punctuation))
    tokens = word_tokenize(some_data)
    stripped_tkns = [re_punk.sub('', wxy) for wxy in tokens]
    lower = [word.lower() for word in stripped_tkns]
    st0p = [word for word in lower if not word in stop_words]
    while "" in st0p: # idk why this happens
        st0p.remove("")
    return st0p

# %%
reviews['Bigrams'] = reviews['MovieReview'].apply(lambda xyz: list(nltk.bigrams(clean_please(xyz))))

# %%
reviews
# Out:
#                  FileName                                        MovieReview  \
# 0   KKN_Doc1_ToxicAvenger  This film believe or not is one of my favorate...
# 1   KKN_Doc2_ToxicAvenger  When I was a teenager, the only available plac...
# 2   KKN_Doc3_ToxicAvenger  I've never seen a Troma film before but I do r...
# 3   KKN_Doc4_ToxicAvenger  Toxic Avenger 21st Anniversary Ed. 2 Disc Set ...
# 4   KKN_Doc5_ToxicAvenger  The Toxic Avenger is an excellent and hilariou...
# 5   KKN_Doc6_ToxicAvenger  I can say the most positive thing about The To...
# 6   KKN_Doc7_ToxicAvenger  The Toxic Avenger starts with a shot of the Ne...
# 7   KKN_Doc8_ToxicAvenger  I have to force myself not to give this movie ...
# 8   KKN_Doc9_ToxicAvenger  Four crazed teenagers speed down the road in t...
# 9  KKN_Doc10_ToxicAvenger  In the world of movies, many know of the main ...
#
#                                              Bigrams  \
# 0  [(film, believe), (believe, one), (one, favora...
# 1  [(teenager, available), (available, place), (p...
# 2  [(never, seen), (seen, troma), (troma, film), ...
# 3  [(toxic, avenger), (avenger, 21st), (21st, ann...
# 4  [(toxic, avenger), (avenger, excellent), (exce...
# 5  [(say, positive), (positive, thing), (thing, t...
# 6  [(toxic, avenger), (avenger, starts), (starts,...
# 7  [(force, give), (give, movie), (movie, anythin...
# 8  [(four, crazed), (crazed, teenagers), (teenage...
# 9  [(world, movies), (movies, many), (many, know)...
#
#                                          Frequencies
# 0  {('film', 'believe'): 1, ('believe', 'one'): 1...
# 1  {('teenager', 'available'): 1, ('available', '...
# 2  {('never', 'seen'): 1, ('seen', 'troma'): 1, (...
# 3  {('toxic', 'avenger'): 3, ('avenger', '21st'):...
# 4  {('toxic', 'avenger'): 21, ('avenger', 'excell...
# 5  {('say', 'positive'): 1, ('positive', 'thing')...
# 6  {('toxic', 'avenger'): 8, ('avenger', 'starts'...
# 7  {('force', 'give'): 1, ('give', 'movie'): 1, (...
# 8  {('four', 'crazed'): 1, ('crazed', 'teenagers'...
# 9  {('world', 'movies'): 1, ('movies', 'many'): 1...

# %%
abc = reviews['Bigrams'][0]

# %%
abc
# Out:
# [('film', 'believe'),
#  ('believe', 'one'),
#  ('one', 'favorate'),
#  ('favorate', 'films'),
#  ('films', 'time'),
#  ('time', 'also'),
#  ('also', 'kinda'),
#  ('kinda', 'another'),
#  ('another', 'one'),
#  ('one', 'childhood'),
#  ('childhood', 'gems'),
#  ('gems', 'well'),
#  ('well', 'like'),
#  ('like', 'teen'),
#  ('teen', 'gems'),
#  ('gems', 'explain'),
#  ('explain', 'kinda'),
#  ('kinda', 'gradual'),
#  ('gradual', 'build'),
#  ('build', 'first'),
#  ('first', 'discovered'),
#  ('discovered', 'franshise'),
#  ('franshise', 'cartoon'),
#  ('cartoon', 'show'),
#  ('show', 'toxic'),
#  ('toxic', 'crusaders'),
#  ('crusaders', 'thought'),
#  ('thought', 'cool'),
#  ('cool', 'nt'),
#  ('nt', 'even'),
#  ('even', 'know'),
#  ('know', 'time'),
#  ('time', 'loosely'),
#  ('loosely', 'inspiredbased'),
#  ('inspiredbased', 'movie'),
#  ('movie', 'toxic'),
#  ('toxic', 'avenger'),
#  ('avenger', 'nt'),
#  ('nt', 'see'),
#  ('see', 'film'),
#  ('film', 'lot'),
#  ('lot', 'latter'),
#  ('latter', 'teenager'),
#  ('teenager', '16'),
#  ('16', 'admit'),
#  ('admit', 'blew'),
#  ('blew', 'away'),
#  ('away', 'nt'),
#  ('nt', 'entirely'),
#  ('entirely', 'expecting'),
#  ('expecting', 'made'),
#  ('made', 'better'),
#  ('better', 'outrageously'),
#  ('outrageously', 'fun'),
#  ('fun', 'funny'),
#  ('funny', 'watching'),
#  ('watching', 'adult'),
#  ('adult', 'even'),
#  ('even', 'fun'),
#  ('fun', 'funner'),
#  ('funner', 'also'),
#  ('also', 'one'),
#  ('one', 'films'),
#  ('films', 'actually'),
#  ('actually', 'inspired'),
#  ('inspired', 'yes'),
#  ('yes', 'kidding'),
#  ('kidding', 'writing'),
#  ('writing', 'getting'),
#  ('getting', 'entertainment'),
#  ('entertainment', 'business'),
#  ('business', 'film'),
#  ('film', 'really'),
#  ('really', 'turned'),
#  ('turned', 'things'),
#  ('things', 'head'),
#  ('head', 'let'),
#  ('let', 'alone'),
#  ('alone', 'turned'),
#  ('turned', 'notch'),
#  ('notch', 'violence'),
#  ('violence', 'effects'),
#  ('effects', 'comidy'),
#  ('comidy', 'superhero'),
#  ('superhero', 'genere'),
#  ('genere', '11'),
#  ('11', 'content'),
#  ('content', 'wild'),
#  ('wild', 'expressionism'),
#  ('expressionism', 'film'),
#  ('film', 'nt'),
#  ('nt', 'common'),
#  ('common', 'place'),
#  ('place', 'time'),
#  ('time', 'defenantly'),
#  ('defenantly', 'tv'),
#  ('tv', 'shows'),
#  ('shows', 'south'),
#  ('south', 'park'),
#  ('park', 'simpsons'),
#  ('simpsons', 'nuts'),
#  ('nuts', 'part'),
#  ('part', 'made'),
#  ('made', 'film'),
#  ('film', 'great'),
#  ('great', 'nt'),
#  ('nt', 'afraid'),
#  ('afraid', 'wanted'),
#  ('wanted', 'fun'),
#  ('fun', 'wanted'),
#  ('wanted', 'film'),
#  ('film', 'made'),
#  ('made', 'low'),
#  ('low', 'budget'),
#  ('budget', 'felt'),
#  ('felt', 'money'),
#  ('money', 'well'),
#  ('well', 'spent'),
#  ('spent', 'showing'),
#  ('showing', 'still'),
#  ('still', 'make'),
#  ('make', 'good'),
#  ('good', 'fun'),
#  ('fun', 'film'),
#  ('film', 'despite'),
#  ('despite', 'limitations'),
#  ('limitations', 'opposed'),
#  ('opposed', 'big'),
#  ('big', 'budget'),
#  ('budget', 'film'),
#  ('film', 'tend'),
#  ('tend', 'disappoint'),
#  ('disappoint', 'forgot'),
#  ('forgot', 'one'),
#  ('one', 'curcial'),
#  ('curcial', 'element'),
#  ('element', 'fun'),
#  ('fun', 'music'),
#  ('music', 'great'),
#  ('great', 'one'),
#  ('one', 'favorate'),
#  ('favorate', 'movie'),
#  ('movie', 'soundtracks'),
#  ('soundtracks', 'really'),
#  ('really', 'like'),
#  ('like', 'song'),
#  ('song', 'body'),
#  ('body', 'talk'),
#  ('talk', 'catchy'),
#  ('catchy', 'tune'),
#  ('tune', 'fun'),
#  ('fun', 'one'),
#  ('one', 'use'),
#  ('use', 'ever'),
#  ('ever', 'want'),
#  ('want', 'aerobics'),
#  ('aerobics', 'fitness'),
#  ('fitness', 'training'),
#  ('training', 'film'),
#  ('film', 'course'),
#  ('course', 'action'),
#  ('action', 'comidy'),
#  ('comidy', 'like'),
#  ('like', 'well'),
#  ('well', 'done'),
#  ('done', 'floor'),
#  ('floor', 'shines'),
#  ('shines', 'comidy'),
#  ('comidy', 'great'),
#  ('great', 'whole'),
#  ('whole', 'thing'),
#  ('thing', 'plays'),
#  ('plays', 'like'),
#  ('like', 'live'),
#  ('live', 'action'),
#  ('action', 'mad'),
#  ('mad', 'magazine'),
#  ('magazine', 'cartoon'),
#  ('cartoon', 'rich'),
#  ('rich', 'verbal'),
#  ('verbal', 'visual'),
#  ('visual', 'humor'),
#  ('humor', 'also'),
#  ('also', 'feel'),
#  ('feel', 'bit'),
#  ('bit', 'replay'),
#  ('replay', 'value'),
#  ('value', 'sometimes'),
#  ('sometimes', 'watching'),
#  ('watching', 'pick'),
#  ('pick', 'jokes'),
#  ('jokes', 'might'),
#  ('might', 'flied'),
#  ('flied', 'characters'),
#  ('characters', 'fun'),
#  ('fun', 'everyone'),
#  ('everyone', 'tromaville'),
#  ('tromaville', 'kinda'),
#  ('kinda', 'live'),
#  ('live', 'action'),
#  ('action', 'mad'),
#  ('mad', 'magazine'),
#  ('magazine', 'characters'),
#  ('characters', 'everyone'),
#  ('everyone', 'totally'),
#  ('totally', 'normal'),
#  ('normal', 'always'),
#  ('always', 'something'),
#  ('something', 'unusal'),
#  ('unusal', 'crazy'),
#  ('crazy', 'villain'),
#  ('villain', 'despite'),
#  ('despite', 'unlikeable'),
#  ('unlikeable', 'point'),
#  ('point', 'still'),
#  ('still', 'funny'),
#  ('funny', 'like'),
#  ('like', 'cigarface'),
#  ('cigarface', 'well'),
#  ('well', 'two'),
#  ('two', 'health'),
#  ('health', 'club'),
#  ('club', 'bullies'),
#  ('bullies', 'slug'),
#  ('slug', 'bozo'),
#  ('bozo', 'true'),
#  ('true', 'names'),
#  ('names', 'let'),
#  ('let', 'alone'),
#  ('alone', 'fact'),
#  ('fact', 'bozo'),
#  ('bozo', 'got'),
#  ('got', 'real'),
#  ('real', 'impulse'),
#  ('impulse', 'problems'),
#  ('problems', 'gets'),
#  ('gets', 'easily'),
#  ('easily', 'stressed'),
#  ('stressed', 'angry'),
#  ('angry', 'smallest'),
#  ('smallest', 'stupidest'),
#  ('stupidest', 'thing'),
#  ('thing', 'cracks'),
#  ('cracks', 'whenever'),
#  ('whenever', 'blows'),
#  ('blows', 'toxicmelvin'),
#  ('toxicmelvin', 'soild'),
#  ('soild', 'superhero'),
#  ('superhero', 'really'),
#  ('really', 'love'),
#  ('love', 'makeup'),
#  ('makeup', 'design'),
#  ('design', 'ugly'),
#  ('ugly', 'actually'),
#  ('actually', 'plesent'),
#  ('plesent', 'looking'),
#  ('looking', 'voice'),
#  ('voice', 'great'),
#  ('great', 'perfectly'),
#  ('perfectly', 'fits'),
#  ('fits', 'strong'),
#  ('strong', 'authoritative'),
#  ('authoritative', 'also'),
#  ('also', 'bit'),
#  ('bit', 'quirky'),
#  ('quirky', 'funny'),
#  ('funny', 'thing'),
#  ('thing', 'person'),
#  ('person', 'tromaville'),
#  ('tromaville', 'actually'),
#  ('actually', 'sane'),
#  ('sane', 'makes'),
#  ('makes', 'sort'),
#  ('sort', 'straight'),
#  ('straight', 'man'),
#  ('man', 'film'),
#  ('film', 'really'),
#  ('really', 'like'),
#  ('like', 'acessable'),
#  ('acessable', 'hero'),
#  ('hero', 'local'),
#  ('local', 'nt'),
#  ('nt', 'go'),
#  ('go', 'justice'),
#  ('justice', 'league'),
#  ('league', 'avengers'),
#  ('avengers', 'always'),
#  ('always', 'busy'),
#  ('busy', 'fighting'),
#  ('fighting', 'big'),
#  ('big', 'threats'),
#  ('threats', 'somewhere'),
#  ('somewhere', 'reason'),
#  ('reason', 'never'),
#  ('never', 'time'),
#  ('time', 'common'),
#  ('common', 'ones'),
#  ('ones', 'weard'),
#  ('weard', 'despite'),
#  ('despite', 'money'),
#  ('money', 'resources'),
#  ('resources', 'stays'),
#  ('stays', 'town'),
#  ('town', 'help'),
#  ('help', 'whoever'),
#  ('whoever', 'trouble'),
#  ('trouble', 'best'),
#  ('best', 'make'),
#  ('make', 'home'),
#  ('home', 'liveable'),
#  ('liveable', 'fancy'),
#  ('fancy', 'weapons'),
#  ('weapons', 'uses'),
#  ('uses', 'whatever'),
#  ('whatever', 'advantage'),
#  ('advantage', 'making'),
#  ('making', 'resourceful'),
#  ('resourceful', 'also'),
#  ('also', 'like'),
#  ('like', 'thoughout'),
#  ('thoughout', 'film'),
#  ('film', 'actions'),
#  ('actions', 'makes'),
#  ('makes', 'tromaville'),
#  ('tromaville', 'safer'),
#  ('safer', 'creates'),
#  ('creates', 'sense'),
#  ('sense', 'community'),
#  ('community', 'underlying'),
#  ('underlying', 'message'),
#  ('message', 'film'),
#  ('film', 'power'),
#  ('power', 'individual'),
#  ('individual', 'community'),
#  ('community', 'really'),
#  ('really', 'like'),
#  ('like', 'use'),
#  ('use', 'satirical'),
#  ('satirical', 'humor'),
#  ('humor', 'pokes'),
#  ('pokes', 'fun'),
#  ('fun', 'suttle'),
#  ('suttle', 'subjects'),
#  ('subjects', 'pointed'),
#  ('pointed', 'underlined'),
#  ('underlined', 'pollution'),
#  ('pollution', 'completely'),
#  ('completely', 'irresponsible'),
#  ('irresponsible', 'amoral'),
#  ('amoral', 'companies'),
#  ('companies', 'handling'),
#  ('handling', 'hazadarious'),
#  ('hazadarious', 'chemicals'),
#  ('chemicals', 'thinking'),
#  ('thinking', 'much'),
#  ('much', 'money'),
#  ('money', 'make'),
#  ('make', 'instead'),
#  ('instead', 'dire'),
#  ('dire', 'consequences'),
#  ('consequences', 'create'),
#  ('create', 'urban'),
#  ('urban', 'crime'),
#  ('crime', 'enough'),
#  ('enough', 'done'),
#  ('done', 'corruption'),
#  ('corruption', 'going'),
#  ('going', 'higher'),
#  ('higher', 'departments'),
#  ('departments', 'well'),
#  ('well', 'powers'),
#  ('powers', 'trying'),
#  ('trying', 'tyrannically'),
#  ('tyrannically', 'control'),
#  ('control', 'indiviuals'),
#  ('indiviuals', 'community'),
#  ('community', 'action'),
#  ('action', 'great'),
#  ('great', 'fights'),
#  ('fights', 'well'),
#  ('well', 'chorigraphed'),
#  ('chorigraphed', 'gore'),
#  ('gore', 'effects'),
#  ('effects', 'par'),
#  ('par', 'really'),
#  ('really', 'like'),
#  ('like', 'action'),
#  ('action', 'begins'),
#  ('begins', 'suspenseful'),
#  ('suspenseful', 'build'),
#  ('build', 'see'),
#  ('see', 'innocentinnocent'),
#  ('innocentinnocent', 'bystanders'),
#  ('bystanders', 'trouble'),
#  ('trouble', 'one'),
#  ('one', 'reason'),
#  ('reason', 'another'),
#  ('another', 'terrorized'),
#  ('terrorized', 'even'),
#  ('even', 'slaughtered'),
#  ('slaughtered', 'really'),
#  ('really', 'awful'),
#  ('awful', 'evil'),
#  ('evil', 'people'),
#  ('people', 'thinking'),
#  ('thinking', 'coming'),
#  ('coming', 'coming'),
#  ('coming', 'minute'),
#  ('minute', 'gets'),
#  ('gets', 'wire'),
#  ('wire', 'toxie'),
#  ('toxie', 'comes'),
#  ('comes', 'cheer'),
#  ('cheer', 'coming'),
#  ('coming', 'clean'),
#  ('clean', 'scum'),
#  ('scum', 'earth'),
#  ('earth', 'one'),
#  ('one', 'favorate'),
#  ('favorate', 'battles'),
#  ('battles', 'time'),
#  ('time', 'battle'),
#  ('battle', 'taco'),
#  ('taco', 'time'),
#  ('time', 'like'),
#  ('like', 'restarurant'),
#  ('restarurant', 'battling'),
#  ('battling', 'gang'),
#  ('gang', 'three'),
#  ('three', 'martial'),
#  ('martial', 'arts'),
#  ('arts', 'one'),
#  ('one', 'one'),
#  ('one', 'fight'),
#  ('fight', 'one'),
#  ('one', 'takes'),
#  ('takes', 'nunchus'),
#  ('nunchus', 'even'),
#  ('even', 'uses'),
#  ('uses', 'katana'),
#  ('katana', 'course'),
#  ('course', 'kills'),
#  ('kills', 'film'),
#  ('film', 'great'),
#  ('great', 'practical'),
#  ('practical', 'gore'),
#  ('gore', 'effects'),
#  ('effects', 'top'),
#  ('top', 'notch'),
#  ('notch', 'kills'),
#  ('kills', 'creative'),
#  ('creative', 'colorful'),
#  ('colorful', 'slight'),
#  ('slight', 'blackly'),
#  ('blackly', 'comic'),
#  ('comic', 'edge'),
#  ('edge', 'sort'),
#  ('sort', 'like'),
#  ('like', 'jason'),
#  ('jason', 'kills'),
#  ('kills', 'friday'),
#  ('friday', '13th'),
#  ('13th', 'films'),
#  ('films', 'difference'),
#  ('difference', 'bad'),
#  ('bad', 'guys'),
#  ('guys', 'toxie'),
#  ('toxie', 'killing'),
#  ('killing', 'get'),
#  ('get', 'deserve'),
#  ('deserve', 'favorate'),
#  ('favorate', 'kill'),
#  ('kill', 'course'),
#  ('course', 'legendary'),
#  ('legendary', 'head'),
#  ('head', 'crushing'),
#  ('crushing', 'scene'),
#  ('scene', 'way'),
#  ('way', 'pertains'),
#  ('pertains', 'subconscious'),
#  ('subconscious', 'fear'),
#  ('fear', 'getting'),
#  ('getting', 'hurt'),
#  ('hurt', 'worse'),
#  ('worse', 'exercise'),
#  ('exercise', 'equipment'),
#  ('equipment', 'well'),
#  ('well', 'said'),
#  ('said', 'enough'),
#  ('enough', 'toxic'),
#  ('toxic', 'avenger'),
#  ('avenger', 'messy'),
#  ('messy', 'fun')]

# %%
from collections import Counter

# %%
reviews['Frequencies'] = reviews['Bigrams'].apply(lambda abc: Counter(abc))

# %%
all_freqs = reviews['Frequencies'][0]+reviews['Frequencies'][1]+reviews['Frequencies'][2]+reviews['Frequencies'][3]+reviews['Frequencies'][4]+reviews['Frequencies'][5]+reviews['Frequencies'][6]+reviews['Frequencies'][7]+reviews['Frequencies'][8]+reviews['Frequencies'][9]

# %%
all_freqs.most_common(40)
# Out:
# [(('toxic', 'avenger'), 54),
#  (('toxic', 'waste'), 18),
#  (('health', 'club'), 6),
#  (('troma', 'entertainment'), 6),
#  (('avenger', 'nt'), 5),
#  (('robert', 'prichard'), 5),
#  (('gary', 'schneider'), 5),
#  (('melvin', 'junko'), 5),
#  (('pat', 'ryan'), 5),
#  (('special', 'effects'), 5),
#  (('mark', 'torgl'), 5),
#  (('andree', 'maranda'), 5),
#  (('blind', 'girl'), 5),
#  (('ca', 'nt'), 5),
#  (('really', 'like'), 4),
#  (('slug', 'robert'), 4),
#  (('bozo', 'gary'), 4),
#  (('cindy', 'manion'), 4),
#  (('junko', 'mark'), 4),
#  (('barrel', 'toxic'), 4),
#  (('troma', 'film'), 4),
#  (('mitch', 'cohen'), 4),
#  (('horror', 'film'), 4),
#  (('lloyd', 'kaufman'), 4),
#  (('one', 'favorate'), 3),
#  (('nt', 'see'), 3),
#  (('low', 'budget'), 3),
#  (('body', 'talk'), 3),
#  (('slug', 'bozo'), 3),
#  (('gore', 'effects'), 3),
#  (('wanda', 'jennifer'), 3),
#  (('jennifer', 'prichard'), 3),
#  (('julie', 'cindy'), 3),
#  (('mop', 'boy'), 3),
#  (('practical', 'joke'), 3),
#  (('waste', 'dumping'), 3),
#  (('cult', 'classic'), 3),
#  (('town', 'tromaville'), 3),
#  (('mitchell', 'cohen'), 3),
#  (('violence', 'gore'), 3)]
