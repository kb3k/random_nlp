# %%
import pandas as pd

# %%
fil_nm = "../../MSDS_453_Public/MSDS453_ClassCorpus/ClassCorpus_Final_v2_20220629.csv"

# %%
df = pd.read_csv(fil_nm)

# %%
df
# Out:
#      Doc_ID            DSI_Title  \
# 0       160        ARE_Doc1_Taxi
# 1       161        ARE_Doc2_Taxi
# 2       162        ARE_Doc3_Taxi
# 3       163        ARE_Doc4_Taxi
# 4       164        ARE_Doc5_Taxi
# ..      ...                  ...
# 195      85   MGB_Doc6_Inception
# 196      86   MGB_Doc7_Inception
# 197      87   MGB_Doc8_Inception
# 198      88   MGB_Doc9_Inception
# 199      89  MGB_Doc10_Inception
#
#                                                   Text Submission File Name  \
# 0    Jimmy Fallon's big screen career may be over b...        ARE_Doc1_Taxi
# 1    After getting nominated for "Chicago" and maki...        ARE_Doc2_Taxi
# 2    Queen Latifah handily walked away with the sho...        ARE_Doc3_Taxi
# 3    So Jimmy Fallon leaves ÒSaturday Night LiveÓ a...        ARE_Doc4_Taxi
# 4    TaxiÊcasts JimmyÊFallon as Officer Andy Washbu...        ARE_Doc5_Taxi
# ..                                                 ...                  ...
# ...

# %%
len(df['Student Name'].unique())
# Out:
# 20
